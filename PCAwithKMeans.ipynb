# %%
import pandas as pd
import pylab as pl
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_variables = pd.read_csv("../Project3/dataforfinalproject/PCAcomponentoutput.csv")

y = raw_variables[['REGIONC']]
x = raw_variables[['TOTALBTU']]

# %%
Nc = range(1, 20)

kmeans = [KMeans(n_clusters=i) for i in Nc]

kmeans
# Out:
# [KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=1, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
# ...

# %%
score = [kmeans[i].fit(y).score(y) for i in range(len(kmeans))]

score
# Out:
# [-533985.7180515988,
#  -65671.88294112305,
#  -40671.03507580654,
#  -21322.757137469194,
#  -12953.783524488992,
#  -8921.375489724995,
#  -6479.522893203641,
#  -5037.938343002059,
#  -4048.9528885584255,
#  -3340.9793235804805,
#  -2746.368830846238,
#  -2310.0557402193085,
#  -1977.3996732472071,
#  -1745.3305065573752,
#  -1524.9717451919298,
#  -1350.2511957666345,
#  -1212.0594713879177,
#  -1085.3884258333644,
#  -988.8115152088668]

# %%
pl.plot(Nc,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.grid()
plt.savefig('C:/Users/justi/Desktop/homework/Project3/dataforfinalproject/Pictures/KMEANSElbow.png')
pl.show()

# %%
pca = PCA(n_components=1).fit(y)

pca_d = pca.transform(y)

pca_c = pca.transform(x)

# %%
kmeans=KMeans(n_clusters=10)

kmeansoutput=kmeans.fit(y)

kmeansoutput
labels = kmeansoutput.labels_
pl.figure('KMeans Cluster of Regions with TOTALBTU')

pl.scatter(pca_c[:, 0], pca_d[:, 0], c=kmeansoutput.labels_)

pl.xlabel('Data Correlation')
pl.grid()
pl.ylabel('Accuracy')
pl.title('KMeans Cluster of Regions with TOTALBTU')
plt.savefig('C:/Users/justi/Desktop/homework/Project3/dataforfinalproject/Pictures/KMEANSCluser.png')
pl.show()
