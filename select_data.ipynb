# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv

raw_2015dt= pd.read_csv("C:/Users/admin/Documents/SMU/Final Project/Data/recs2015.csv")
raw_2015dt.head()
# Out:
#    DOEID  REGIONC  DIVISION METROMICRO UATYP10  TYPEHUQ  ZTYPEHUQ  CELLAR  \
# 0  10001        4        10      METRO       U        2         0       0
# 1  10002        3         7       NONE       R        2         0       0
# 2  10003        3         6      METRO       U        2         0       1
# 3  10004        2         4      MICRO       C        2         0       1
# 4  10005        1         2      METRO       U        2         0       1
#
#    ZCELLAR  BASEFIN    ...      ZELAMOUNT  NGXBTU  PERIODNG  ZNGAMOUNT  \
# 0        0       -2    ...              0  103.32         1          0
# 1        0       -2    ...              1     NaN        -2         -2
# 2        0        1    ...              0  100.14         1          0
# 3        0        1    ...              0     NaN        -2         -2
# 4        0        0    ...              0  102.83         1          0
#
#    FOXBTU  PERIODFO  ZFOAMOUNT  LPXBTU  PERIODLP  ZLPAMOUNT
# ...

# %%
raw_2015dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5686 entries, 0 to 5685
# Columns: 759 entries, DOEID to ZLPAMOUNT
# dtypes: float64(262), int64(493), object(4)
# memory usage: 32.9+ MB

# %%
# Drop all columns starting Z and DoIDE
# Count is given by NWEIGHT

# %%
## Data Filtering (specific colums, row conditions)
# extract only required cols
#raw_2015_df = raw_2015dt[['DOEID','TYPEHUQ','STORIES','SIZEOFGARAGE','KOWNRENT','YEARMADERANGE','ADQINSUL',
   #                       'TOTSQFT_EN','WINDOWS','KWH']]
#raw_2015_df.head()
# Descriptive statistics for each column
#raw_2015dt.describe()

# %%
# Descriptive statistics for each column
raw_2015dt.describe()
# Out:
#               DOEID      REGIONC     DIVISION      TYPEHUQ  ZTYPEHUQ  \
# count   5686.000000  5686.000000  5686.000000  5686.000000    5686.0
# mean   12843.500000     2.760816     5.670243     2.596025       0.0
# std     1641.551147     1.004187     2.842655     1.164641       0.0
# min    10001.000000     1.000000     1.000000     1.000000       0.0
# 25%    11422.250000     2.000000     3.000000     2.000000       0.0
# 50%    12843.500000     3.000000     5.000000     2.000000       0.0
# 75%    14264.750000     4.000000     8.000000     3.000000       0.0
# max    15686.000000     4.000000    10.000000     5.000000       0.0
#
#             CELLAR      ZCELLAR      BASEFIN     ZBASEFIN        ATTIC  \
# count  5686.000000  5686.000000  5686.000000  5686.000000  5686.000000
# mean     -0.205593    -0.505276    -1.199261    -1.381815    -0.111854
# std       1.134775     0.880288     1.235166     0.933693     1.187953
# ...
