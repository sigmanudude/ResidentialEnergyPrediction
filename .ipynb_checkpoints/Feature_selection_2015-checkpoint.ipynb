# %%
import pandas as pd
import matplotlib as plt

# %%
import seaborn as sns

# %%
from feature_selector import FeatureSelector

# %%
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('recs2015_public_v4.csv')
train_labels = train['TOTALDOL']
train.head()
# Out:
#    DOEID  REGIONC  DIVISION METROMICRO UATYP10  TYPEHUQ  ZTYPEHUQ  CELLAR  \
# 0  10001        4        10      METRO       U        2         0       0
# 1  10002        3         7       NONE       R        2         0       0
# 2  10003        3         6      METRO       U        2         0       1
# 3  10004        2         4      MICRO       C        2         0       1
# 4  10005        1         2      METRO       U        2         0       1
#
#    ZCELLAR  BASEFIN    ...      ZELAMOUNT  NGXBTU  PERIODNG  ZNGAMOUNT  \
# 0        0       -2    ...              0  103.32         1          0
# 1        0       -2    ...              1     NaN        -2         -2
# 2        0        1    ...              0  100.14         1          0
# 3        0        1    ...              0     NaN        -2         -2
# 4        0        0    ...              0  102.83         1          0
#
#    FOXBTU  PERIODFO  ZFOAMOUNT  LPXBTU  PERIODLP  ZLPAMOUNT
# 0  137.45        -2         -2   91.33        -2         -2
# 1  137.45        -2         -2   91.33        -2         -2
# 2  137.45        -2         -2   91.33        -2         -2
# 3  137.45        -2         -2   91.33         2          0
# 4  137.45        -2         -2   91.33        -2         -2
#
# [5 rows x 759 columns]

# %%
train = train.drop(columns = ['TOTALDOL'])

# %%
train=train.drop(columns=["ZTYPEHUQ","ZCELLAR","ZBASEFIN","ZATTIC","ZATTICFIN","ZSTORIES","ZPRKGPLC1","ZSIZEOFGARAGE","ZKOWNRENT","ZYEARMADERANGE","ZOCCUPYYRANGE","ZSTUDIO","ZBEDROOMS","ZNCOMBATH","ZNHAFBATH","ZOTHROOMS","ZTOTROOMS","ZWALLTYPE","ZROOFTYPE","ZHIGHCEIL","ZDOOR1SUM","ZWINDOWS","ZTYPEGLASS","ZWINFRAME","ZADQINSUL","ZDRAFTY","ZUGASHERE","ZSWIMPOOL","ZMONPOOL","ZPOOL","ZFUELPOOL","ZRECBATH","ZMONTUB","ZFUELTUB","ZOUTLET","ZALTFUELPEV","ZBACKUP","ZNUMFRIG","ZSIZRFRI1","ZTYPERFR1","ZAGERFRI1","ZICE","ZSIZRFRI2","ZTYPERFR2","ZAGERFRI2","ZLOCRFRI2","ZNUMFREEZ","ZUPRTFRZR","ZSIZFREEZ","ZAGEFRZR","ZSTOVEN","ZSTOVENFUEL","ZDUALCOOKTFUEL","ZDUALOVENFUEL","ZCOOKTUSE","ZOVENUSE","ZSTOVE","ZSTOVEFUEL","ZSEPCOOKTUSE","ZOVEN","ZOVENFUEL","ZSEPOVENUSE","ZMICRO","ZAMTMICRO","ZOUTGRILL","ZOUTGRILLFUEL","ZNUMMEAL","ZTOAST","ZTOASTOVN","ZCOFFEE","ZCROCKPOT","ZFOODPROC","ZRICECOOK","ZBLENDER","ZAPPOTHER","ZDISHWASH","ZDWASHUSE","ZDWCYCLE","ZAGEDW","ZCWASHER","ZTOPFRONT","ZWASHLOAD","ZWASHTEMP","ZRNSETEMP","ZAGECWASH","ZDRYER","ZDRYRFUEL","ZDRYRUSE","ZAGECDRYER","ZTVCOLOR","ZTVSIZE1","ZTVTYPE1","ZTVONWD1","ZTVONWE1","ZTVSIZE2","ZTVTYPE2","ZTVONWD2","ZTVONWE2","ZCABLESAT","ZCOMBODVR","ZSEPDVR","ZPLAYSTA","ZDVD","ZVCR","ZINTSTREAM","ZTVAUDIOSYS","ZDESKTOP","ZNUMLAPTOP","ZNUMTABLET","ZELPERIPH","ZNUMSMPHONE","ZCELLPHONE","ZINTERNET","ZINWIRELESS","ZHEATHOME","ZDNTHEAT","ZEQUIPM","ZFUELHEAT","ZEQUIPAGE","ZTHERMAIN","ZPROTHERM","ZEQUIPMUSE","ZTEMPHOME","ZTEMPGONE","ZTEMPNITE","ZEQUIPAUX","ZEQUIPAUXTYPE","ZFUELAUX","ZBASEHEAT","ZATTCHEAT","ZGARGHEAT","ZMOISTURE","ZUSEMOISTURE","ZAIRCOND","ZCOOLTYPE","ZCENACHP","ZAGECENAC","ZTHERMAINAC","ZPROTHERMAC","ZUSECENAC","ZNUMBERAC","ZWWACAGE","ZUSEWWAC","ZTEMPHOMEAC","ZTEMPGONEAC","ZTEMPNITEAC","ZBASECOOL","ZATTCCOOL","ZGARGCOOL","ZSWAMPCOL","ZNUMCFAN","ZNUMFLOORFAN","ZNUMWHOLEFAN","ZNUMATTICFAN","ZNOTMOIST","ZUSENOTMOIST","ZFUELH2O","ZH2OHEATAPT","ZWHEATAGE","ZWHEATSIZ","ZMORETHAN1H2O","ZFUELH2O2","ZLGTINNUM","ZLGTIN4","ZLGTINCAN","ZLGTINCFL","ZLGTINLED","ZLGTINCNTL","ZLGTOUTNUM","ZLGTOUTCNTL","ZELPAY","ZNGPAY","ZLPGPAY","ZFOPAY","ZHHSEX","ZHHAGE","ZEMPLOYHH","ZSDESCENT","ZHOUSEHOLDER_RACE","ZEDUCATION","ZNHSLDMEM","ZNUMADULT","ZNUMCHILD","ZATHOME","ZMONEYPY","ZENERGYASST","ZENERGYASST11","ZENERGYASST12","ZENERGYASST13","ZENERGYASST14","ZENERGYASST15","ZENERGYASSTOTH","ZSCALEB","ZSCALEG","ZSCALEE","ZPAYHELP","ZNOHEATBROKE","ZNOHEATEL","ZNOHEATNG","ZNOHEATBULK","ZNOHEATDAYS","ZNOHEATHELP","ZCOLDMA","ZNOACBROKE","ZNOACEL","ZNOACDAYS","ZNOACHELP","ZHOTMA","ZWOODLOGS","ZWDPELLET","ZTOTSQFT_EN","ZWOODAMT","ZPELLETAMT","ZELAMOUNT","ZNGAMOUNT","ZFOAMOUNT","ZLPAMOUNT"])

# %%
train_bk=train
train=train.drop(columns=['DOEID','METROMICRO','UATYP10','CLIMATE_REGION_PUB','IECC_CLIMATE_PUB','NGXBTU'])

# %%
train_scaler = pd.DataFrame(StandardScaler().fit_transform(train.values), columns=train.columns, index=train.index)

# %%
train_labels_scaler = StandardScaler().fit_transform(train_labels.values.reshape(-1,1))

# %%
fs = FeatureSelector(data = train_scaler, labels = train_labels_scaler)

# %%
# fs.identify_all(selection_params = {'missing_threshold': 0.6, 'correlation_threshold': 0.98, 
#                                     'task': 'classification', 'eval_metric': 'auc', 
#                                      'cumulative_importance': 0.99})

# %%
fs.identify_missing(missing_threshold=0.6)
# Out:
# 0 features with greater than 0.60 missing values.

# %%
fs.identify_single_unique()
# Out:
# 4 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
single_unique
# Out:
# ['USEEL', 'ELOTHER', 'ELXBTU', 'LPXBTU']

# %%
fs.unique_stats.sample(5)
# Out:
#               nunique
# TVSIZE1             5
# TOPFRONT            3
# BRRWT12          5208
# OUTGRILLFUEL        5
# BRRWT17          5208

# %%
fs.identify_collinear(correlation_threshold=0.975)
# Out:
# 76 features with a correlation magnitude greater than 0.97.

# %%
correlated_features = fs.ops['collinear']
correlated_features[:5]
# Out:
# ['SOLAR', 'DNTHEAT', 'TEMPHOMEAC', 'TEMPGONEAC', 'TEMPNITEAC']

# %%
fs.plot_collinear()

# %%
fs.identify_collinear(correlation_threshold=0.98)
fs.plot_collinear()
# Out:
# 72 features with a correlation magnitude greater than 0.98.

# %%
fs.record_collinear
# Out:
#       drop_feature  corr_feature  corr_value
# 0            SOLAR        STUDIO   -0.977165
# 1          DNTHEAT      HEATHOME   -0.990174
# 2       TEMPHOMEAC       AIRCOND    0.984389
# 3       TEMPGONEAC       AIRCOND    0.979701
# 4       TEMPGONEAC    TEMPHOMEAC    0.987929
# 5       TEMPNITEAC       AIRCOND    0.983396
# 6       TEMPNITEAC    TEMPHOMEAC    0.991136
# 7       TEMPNITEAC    TEMPGONEAC    0.985425
# 8       H2OHEATAPT        STUDIO    0.976319
# 9       H2OHEATAPT         SOLAR   -0.977274
# 10    ENERGYASST11    ENERGYASST    0.979946
# 11    ENERGYASST12    ENERGYASST    0.978957
# 12    ENERGYASST12  ENERGYASST11    0.988059
# 13    ENERGYASST13    ENERGYASST    0.978607
# 14    ENERGYASST13  ENERGYASST11    0.981619
# 15    ENERGYASST13  ENERGYASST12    0.983398
# 16    ENERGYASST14    ENERGYASST    0.979585
# 17    ENERGYASST14  ENERGYASST12    0.975121
# 18    ENERGYASST14  ENERGYASST13    0.978531
# 19    ENERGYASST15    ENERGYASST    0.980486
# 20   ENERGYASSTOTH    ENERGYASST    0.984040
# 21          ELCOOL       AIRCOND    1.000000
# 22          ELCOOL    TEMPHOMEAC    0.984389
# 23          ELCOOL    TEMPGONEAC    0.979701
# 24          ELCOOL    TEMPNITEAC    0.983396
# 25          FOWARM         USEFO    0.981936
# 26        WOODLOGS       USEWOOD    0.996587
# 27        WDPELLET       USEWOOD    0.990881
# 28        WDPELLET      WOODLOGS    0.978106
# 29         WDOTHER       USEWOOD    0.998038
# ..             ...           ...         ...
# 77           BTULP      GALLONLP    1.000000
# 78        BTULPSPH   GALLONLPSPH    1.000000
# 79        BTULPWTH   GALLONLPWTH    1.000000
# 80        BTULPCOK   GALLONLPCOK    1.000000
# 81        BTULPCDR   GALLONLPCDR    1.000000
# 82        BTULPNEC   GALLONLPNEC    1.000000
# 83     GALLONFOSPH      GALLONFO    0.985613
# 84           BTUFO      GALLONFO    0.999989
# 85           BTUFO   GALLONFOSPH    0.985617
# 86        BTUFOSPH      GALLONFO    0.985581
# 87        BTUFOSPH   GALLONFOSPH    0.999989
# 88        BTUFOSPH         BTUFO    0.985607
# 89        BTUFOWTH   GALLONFOWTH    0.999991
# 90        BTUFONEC   GALLONFONEC    0.999980
# 91        DOLLARFO      GALLONFO    0.989496
# 92        DOLLARFO         BTUFO    0.989331
# 93        DOLFOSPH      GALLONFO    0.975413
# 94        DOLFOSPH   GALLONFOSPH    0.989633
# 95        DOLFOSPH         BTUFO    0.975264
# 96        DOLFOSPH      BTUFOSPH    0.989468
# 97        DOLFOSPH      DOLLARFO    0.985413
# 98        DOLFOWTH   GALLONFOWTH    0.994128
# 99        DOLFOWTH      BTUFOWTH    0.994046
# 100       DOLFONEC   GALLONFONEC    0.985599
# 101       DOLFONEC      BTUFONEC    0.984959
# 102    TOTALDOLCDR      DOLELCDR    0.987430
# 103     TOTALDOLPL    DOLELPLPMP    0.982620
# 104    TOTALBTUHTB     KWHHTBPMP    0.987347
# 105    TOTALBTUHTB   BTUELHTBPMP    0.987347
# 106      PELLETBTU     PELLETAMT    0.998204
#
# [107 rows x 3 columns]

# %%
fs.identify_zero_importance(task = 'regression', eval_metric = 'l2', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [853]	valid_0's l2: 0.0236891	valid_0's l2: 0.0236891
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [220]	valid_0's l2: 0.00879424	valid_0's l2: 0.00879424
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [973]	valid_0's l2: 0.0258835	valid_0's l2: 0.0258835
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [460]	valid_0's l2: 0.014657	valid_0's l2: 0.014657
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [993]	valid_0's l2: 0.0314093	valid_0's l2: 0.0314093
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [998]	valid_0's l2: 0.0098953	valid_0's l2: 0.0098953
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [988]	valid_0's l2: 0.021898	valid_0's l2: 0.021898
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [318]	valid_0's l2: 0.0235145	valid_0's l2: 0.0235145
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [366]	valid_0's l2: 0.0134396	valid_0's l2: 0.0134396
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [766]	valid_0's l2: 0.0229415	valid_0's l2: 0.0229415
#
# 42 features with zero importance after one-hot encoding.

# %%
one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# There are 535 original features
# There are 0 one-hot features

# %%
zero_importance_features = fs.ops['zero_importance']
zero_importance_features
# Out:
# ['ELXBTU',
#  'PELLETBTU',
#  'NOACEL',
#  'NOACHELP',
#  'HOTMA',
#  'USEEL',
#  'LPXBTU',
#  'ELCOOL',
#  'WDOTHER',
#  'SOLWATER',
#  'ELOTHER',
#  'USENG',
#  'ENERGYASST13',
#  'FOOTHER',
#  'USELP',
#  'USEFO',
#  'WDWARM',
#  'WDWATER',
#  'ENERGYASST12',
#  'BTULP',
#  'BTUELSPH',
#  'BTULPSPH',
#  'BTULPWTH',
#  'BTULPCOK',
#  'BTULPCDR',
#  'BTULPNEC',
#  'BTUELHTBPMP',
#  'BTUELPLPMP',
#  'BTUELHUM',
#  'BTUELDHUM',
#  'BTUELEVAPCOL',
#  'BTUELHTBHEAT',
#  'BTUELTV2',
#  'NOHEATNG',
#  'GALLONFONEC',
#  'BTUELLGT',
#  'BTUELCDR',
#  'BTUFONEC',
#  'BTUELWTH',
#  'DOLFONEC',
#  'BTUELCOL',
#  'WDPELLET']

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 20)
# Out:
# 379 features required for 0.99 of cumulative importance

# %%
fs.feature_importances.count()
# Out:
# feature                  535
# importance               535
# normalized_importance    535
# cumulative_importance    535
# dtype: int64

# %%
top_features = list(fs.feature_importances.loc[:380, 'feature'])
len(top_features)
# Out:
# 381

# %%
top_features
# Out:
# ['DOLLAREL',
#  'TOTALBTU',
#  'TOTALDOLSPH',
#  'DOLLARNG',
#  'KWH',
#  'TOTALDOLNEC',
#  'DOLLARLP',
#  'TOTALBTUSPH',
#  'DOLLPCOK',
#  'TOTALDOLWTH',
#  'TOTSQFT_EN',
#  'KWHPLPMP',
#  'DOLELPLPMP',
#  'GALLONLP',
#  'DOLELCW',
#  'DOLELNEC',
#  'GALLONLPCOK',
#  'DOLNGSPH',
#  'DOLELRFG1',
#  'DOLELCOL',
#  'DOLELDHUM',
#  'TOTALDOLCOK',
#  'TOTALBTUWTH',
#  'TOTALBTUNEC',
#  'KWHNEC',
#  'DOLLARFO',
#  'BTUNGCDR',
#  'KWHSPH',
#  'DOLLPSPH',
#  'BTUNG',
#  'KWHRFG1',
#  'CUFEETNG',
#  'TOTALBTUPL',
#  'DOLELLGT',
#  'KWHRFG',
#  'GALLONFO',
#  'DOLELTVREL',
#  'GALLONLPSPH',
#  'DOLELDWH',
#  'DOLNGWTH',
#  'TOTALBTUCOK',
#  'TOTHSQFT',
#  'DOLELRFG',
#  'DOLLPWTH',
#  'DOLELMICRO',
#  'DOLELAHUCOL',
#  'KWHWTH',
#  'GALLONFOSPH',
#  'TOTUCSQFT',
#  'DOLELSPH',
#  'DOLFOSPH',
#  'DOLELFRZ',
#  'KWHAHUHEAT',
#  'KWHLGT',
#  'DOLELTV1',
#  'TOTCSQFT',
#  'DOLNGCOK',
#  'KWHTVREL',
#  'HHAGE',
#  'DOLELAHUHEAT',
#  'CUFEETNGCDR',
#  'GALLONLPWTH',
#  'DOLELTV2',
#  'KWHMICRO',
#  'BRRWT84',
#  'TOTALDOLPL',
#  'LGTIN4',
#  'DOLELCDR',
#  'DOLELRFG2',
#  'BRRWT46',
#  'KWHTV1',
#  'BRRWT36',
#  'DOLNGPLHEAT',
#  'DBT1',
#  'BRRWT13',
#  'CUFEETNGNEC',
#  'BRRWT95',
#  'BRRWT20',
#  'BRRWT66',
#  'KWHCFAN',
#  'BRRWT6',
#  'BRRWT63',
#  'BRRWT18',
#  'BRRWT73',
#  'BRRWT60',
#  'DOLELCFAN',
#  'BRRWT12',
#  'BRRWT59',
#  'BRRWT96',
#  'BRRWT94',
#  'BRRWT75',
#  'BRRWT78',
#  'FUELHEAT',
#  'DOLNGNEC',
#  'BRRWT19',
#  'BRRWT87',
#  'BRRWT42',
#  'BRRWT22',
#  'BRRWT71',
#  'BRRWT21',
#  'BRRWT35',
#  'BRRWT41',
#  'BRRWT50',
#  'BRRWT76',
#  'KWHTV2',
#  'BRRWT86',
#  'BRRWT72',
#  'BRRWT28',
#  'KWHCOK',
#  'BRRWT27',
#  'BRRWT48',
#  'BRRWT85',
#  'BRRWT4',
#  'BRRWT8',
#  'BRRWT45',
#  'KWHCW',
#  'BRRWT90',
#  'BRRWT44',
#  'BRRWT81',
#  'BRRWT56',
#  'BRRWT9',
#  'BRRWT92',
#  'BRRWT83',
#  'KWHCOL',
#  'BRRWT49',
#  'BRRWT64',
#  'BRRWT30',
#  'BRRWT17',
#  'BRRWT15',
#  'BRRWT55',
#  'BRRWT24',
#  'BRRWT7',
#  'CUFEETNGSPH',
#  'BRRWT26',
#  'BRRWT67',
#  'BRRWT43',
#  'BRRWT79',
#  'BRRWT25',
#  'BRRWT37',
#  'TEMPGONE',
#  'KWHHUM',
#  'BRRWT54',
#  'BRRWT68',
#  'BRRWT23',
#  'BRRWT80',
#  'BRRWT5',
#  'BRRWT39',
#  'TOTALBTUCDR',
#  'BRRWT29',
#  'BRRWT77',
#  'BRRWT31',
#  'BRRWT3',
#  'BRRWT52',
#  'BRRWT82',
#  'BRRWT65',
#  'BRRWT14',
#  'GALLONLPCDR',
#  'BRRWT61',
#  'DOLELHUM',
#  'BRRWT51',
#  'BRRWT33',
#  'OA_LAT',
#  'BRRWT69',
#  'BRRWT34',
#  'BRRWT40',
#  'BRRWT70',
#  'CDD80',
#  'DOLLPCDR',
#  'BRRWT53',
#  'GNDHDD65',
#  'BRRWT47',
#  'TEMPNITE',
#  'BRRWT1',
#  'BTUNGNEC',
#  'BRRWT58',
#  'BRRWT62',
#  'TOTALDOLCDR',
#  'DOLELCOK',
#  'REGIONC',
#  'COOKTUSE',
#  'BRRWT2',
#  'BRRWT16',
#  'BRRWT74',
#  'BRRWT38',
#  'BRRWT10',
#  'DBT99',
#  'BRRWT57',
#  'BRRWT89',
#  'KWHDWH',
#  'KWHAHUCOL',
#  'DOLFOWTH',
#  'BRRWT91',
#  'BRRWT32',
#  'BRRWT11',
#  'CDD30YR',
#  'OVENUSE',
#  'BRRWT88',
#  'CUFEETNGWTH',
#  'BRRWT93',
#  'BTUNGSPH',
#  'HDD30YR',
#  'CDD65',
#  'TOTUSQFT',
#  'TEMPHOME',
#  'DOLELWTH',
#  'HDD65',
#  'KWHCDR',
#  'CUFEETNGPLHEAT',
#  'TVCOLOR',
#  'BTUNGWTH',
#  'COMBODVR',
#  'DOLLPNEC',
#  'WSF',
#  'KWHFRZ',
#  'HDD50',
#  'OCCUPYYRANGE',
#  'TEMPGONEAC',
#  'MONPOOL',
#  'EQUIPAGE',
#  'DIVISION',
#  'TEMPNITEAC',
#  'EQUIPAUXTYPE',
#  'TEMPHOMEAC',
#  'NUMCFAN',
#  'LGTINCFL',
#  'FUELH2O',
#  'ATHOME',
#  'FUELAUX',
#  'GALLONLPNEC',
#  'GWT',
#  'GALLONFOWTH',
#  'EQUIPM',
#  'WHEATAGE',
#  'TVTYPE1',
#  'LGTINCAN',
#  'TOTROOMS',
#  'BTUNGPLHEAT',
#  'YEARMADERANGE',
#  'TOTALBTUHTB',
#  'KWHDHUM',
#  'WINDOWS',
#  'CABLESAT',
#  'NUMMEAL',
#  'BEDROOMS',
#  'DOLNGCDR',
#  'NCOMBATH',
#  'NWEIGHT',
#  'TVTYPE2',
#  'MONEYPY',
#  'NUMFLOORFAN',
#  'AGERFRI1',
#  'NHSLDMEM',
#  'DRYRUSE',
#  'DOLNGHTBHEAT',
#  'NUMADULT',
#  'DOLELHTBPMP',
#  'OTHROOMS',
#  'NUMLAPTOP',
#  'AMTMICRO',
#  'AGECWASH',
#  'KWHRFG2',
#  'DRAFTY',
#  'EQUIPMUSE',
#  'LPGPAY',
#  'CELLPHONE',
#  'PERIODFO',
#  'WINFRAME',
#  'NHAFBATH',
#  'AGEDW',
#  'DVD',
#  'CUFEETNGCOK',
#  'NUMSMPHONE',
#  'TYPERFR1',
#  'TVSIZE1',
#  'SEPOVENUSE',
#  'EDUCATION',
#  'WALLTYPE',
#  'LGTINLED',
#  'ELPERIPH',
#  'WASHLOAD',
#  'AGECDRYER',
#  'PLAYSTA',
#  'AGECENAC',
#  'LGTINNUM',
#  'UGASHERE',
#  'TVSIZE2',
#  'VCR',
#  'PERIODLP',
#  'TVONWE2',
#  'USECENAC',
#  'NUMTABLET',
#  'WWACAGE',
#  'CUFEETNGHTBHEAT',
#  'TVONWE1',
#  'WHEATSIZ',
#  'USENOTMOIST',
#  'SIZRFRI1',
#  'TYPEGLASS',
#  'DESKTOP',
#  'OUTGRILLFUEL',
#  'NUMBERAC',
#  'TVONWD1',
#  'SMARTMETER',
#  'USEMOISTURE',
#  'KWHHTBPMP',
#  'ADQINSUL',
#  'HHSEX',
#  'ESDISHW',
#  'AGEFRZR',
#  'SIZFREEZ',
#  'ESLIGHT',
#  'RNSETEMP',
#  'CROCKPOT',
#  'ESDRYER',
#  'ROOFTYPE',
#  'LOCRFRI2',
#  'BTUNGCOK',
#  'WASHTEMP',
#  'USEWWAC',
#  'DOLELHTBHEAT',
#  'ESCWASH',
#  'INTSTREAM',
#  'HOUSEHOLDER_RACE',
#  'DWCYCLE',
#  'DOOR1SUM',
#  'ICE',
#  'INTDATAACC',
#  'AGERFRI2',
#  'SCALEB',
#  'BTUELAHUCOL',
#  'EMPLOYHH',
#  'BASEFIN',
#  'INTDATA',
#  'STOVENFUEL',
#  'TOASTOVN',
#  'ESWATER',
#  'NUMCHILD',
#  'ESFRIG',
#  'REBATEAPP',
#  'FOPAY',
#  'NUMATTICFAN',
#  'LGTOUTNUM',
#  'LGTOUTCNTL',
#  'TYPERFR2',
#  'NGPAY',
#  'ELWATER',
#  'TVAUDIOSYS',
#  'SIZRFRI2',
#  'TOAST',
#  'FUELPOOL',
#  'COOLTYPE',
#  'ESWIN',
#  'PRKGPLC1',
#  'EQUIPAUX',
#  'TVONWD2',
#  'OUTLET',
#  'ESFREEZE',
#  'FOXBTU',
#  'NUMFREEZ',
#  'BTUFOSPH',
#  'MORETHAN1H2O',
#  'LGTINCNTL',
#  'LPOTHER',
#  'PROTHERM',
#  'ATTCHEAT',
#  'NOACDAYS',
#  'SMARTTHERM',
#  'COFFEE',
#  'HIGHCEIL',
#  'TOTALDOLHTB',
#  'SEPCOOKTUSE',
#  'SCALEE',
#  'STORIES',
#  'GARGHEAT',
#  'WOODBTU',
#  'DWASHUSE',
#  'TYPEHUQ',
#  'BTUEL',
#  'UGWARM',
#  'GARGCOOL',
#  'ENERGYASST']

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
# Out:
# 378 features required for cumulative importance of 0.99 after one hot encoding.
# 157 features do not contribute to cumulative importance of 0.99.

# %%
train_removed = fs.remove(methods = 'all')
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 180 features.

# %%
train_removed.columns
# Out:
# Index(['REGIONC', 'DIVISION', 'TYPEHUQ', 'BASEFIN', 'STORIES', 'PRKGPLC1',
#        'YEARMADERANGE', 'OCCUPYYRANGE', 'BEDROOMS', 'NCOMBATH',
#        ...
#        'TOTALDOLCOK', 'TOTALBTUCDR', 'TOTALBTUPL', 'TOTALDOLHTB',
#        'TOTALBTUNEC', 'TOTALDOLNEC', 'WOODBTU', 'FOXBTU', 'PERIODFO',
#        'PERIODLP'],
#       dtype='object', length=355)

# %%
train.columns
# Out:
# Index(['REGIONC', 'DIVISION', 'TYPEHUQ', 'CELLAR', 'BASEFIN', 'ATTIC',
#        'ATTICFIN', 'STORIES', 'PRKGPLC1', 'SIZEOFGARAGE',
#        ...
#        'WOODBTU', 'PELLETAMT', 'PELLETBTU', 'ELXBTU', 'PERIODEL', 'PERIODNG',
#        'FOXBTU', 'PERIODFO', 'LPXBTU', 'PERIODLP'],
#       dtype='object', length=535)

# %%
train_removed_all = fs.remove(methods = 'all', keep_one_hot=False)
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 180 features including one-hot features.

# %%
print('Original Number of Features', train.shape[1])
print('Final Number of Features: ', train_removed_all.shape[1])
# Out:
# Original Number of Features 535
# Final Number of Features:  355

# %%
train_removed_all.to_csv('2015_feature_selection.csv',index=False)
