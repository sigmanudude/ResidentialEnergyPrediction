# %%
# Generic Dependencies
import numpy as np
from numpy import arange
import pandas as pd
from pandas import set_option
# from pandas.tools.plotting import scatter_matrix
import os

# Plotting Libraries
from matplotlib import pyplot as plt
import seaborn as sns

# SKLearn Libraries
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso, LassoCV, Ridge,RidgeCV
from sklearn.model_selection import cross_validate

# library for saving models
from sklearn.externals import joblib

from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error

# DictVectorizer
from sklearn.feature_extraction import DictVectorizer

#XGBoost libraries
import xgboost as xgb

# explain xgboost preiction and model
import shap


# import generateXdata.py to prepare the data
# from generateXdata import generateX
from generateXdataExt import generateX_samp

#Import Custom ml models
from Cls_ml_models import ml_models_tuned

# %%
# gobal variables
dataFilePath = "dataforfinalproject"
filename = "sampletest.csv"
cols_file = "Final_Columns_withCat.csv"
sample = "SAMPLE 5"

totsqt = {0 : "(df_recs.TOTHSQFT != -1)",
             1 : "(df_recs.TOTHSQFT < 900)",
             2 : "((df_recs.TOTHSQFT >= 900) & (df_recs.TOTHSQFT < 1500))",
             3 : "((df_recs.TOTHSQFT >= 1500) & (df_recs.TOTHSQFT < 2500))",
             4 : "((df_recs.TOTHSQFT >= 2500) & (df_recs.TOTHSQFT < 3500))",
             5 : "(df_recs.TOTHSQFT >= 3500)"}

# %%
X, vocab, y = generateX_samp(ohe = True, target = "DOLLAR", numSamples = 30, region = 2, totsqft_cd = 3)
# Out:
#        RECSYEAR        COUNTRY  DOEID  REGIONC REGIONNAME  DIVISION  \
# 4371       2001  United States   5540        2    Midwest         3
# 5223       2009  United States    596        2    Midwest         4
# 10554      2009  United States   6308        2    Midwest         4
# 18167      2015  United States  12282        2    Midwest         3
# 2193       2001  United States   3279        2    Midwest         3
# 8451       2009  United States   4054        2    Midwest         4
# 12015      2009  United States   7872        2    Midwest         4
# 12875      2009  United States   8780        2    Midwest         3
# 20455      2015  United States  14656        2    Midwest         3
# 10994      2009  United States   6781        2    Midwest         4
# 42         2001  United States   1044        2    Midwest         3
# 9375       2009  United States   5059        2    Midwest         3
# 4684       2009  United States     22        2    Midwest         3
# 4629       2001  United States   5818        2    Midwest         4
# 2328       2001  United States   3419        2    Midwest         3
# 15843      2009  United States  11951        2    Midwest         3
# 11258      2009  United States   7066        2    Midwest         3
# 3378       2001  United States   4512        2    Midwest         4
# 19966      2015  United States  14149        2    Midwest         3
# 15890      2009  United States  12001        2    Midwest         4
# 7935       2009  United States   3512        2    Midwest         4
# 11944      2009  United States   7796        2    Midwest         4
# 12066      2009  United States   7924        2    Midwest         4
# 18700      2015  United States  12829        2    Midwest         4
# 19398      2015  United States  13554        2    Midwest         4
# 16887      2015  United States  10949        2    Midwest         4
# 5306       2009  United States    684        2    Midwest         4
# 12202      2009  United States   8069        2    Midwest         4
# 15408      2009  United States  11489        2    Midwest         3
# 6224       2009  United States   1675        2    Midwest         4
#
#              DIVISIONNAME  TYPEHUQ  CELLAR  STORIES  ...  WDPELLET  WDOTHER  \
# 4371   East North Central        2     1.0     20.0  ...       9.0      0.0
# 5223   West North Central        2     1.0     10.0  ...       0.0      0.0
# 10554  West North Central        2     1.0     10.0  ...       0.0      0.0
# 18167  East North Central        2     0.0     10.0  ...       0.0      0.0
# 2193   East North Central        1     9.0     10.0  ...       9.0      0.0
# 8451   West North Central        2     1.0     10.0  ...       0.0      0.0
# 12015  West North Central        2     0.0     20.0  ...       0.0      0.0
# 12875  East North Central        2     1.0     20.0  ...       0.0      0.0
# 20455  East North Central        2     0.0     20.0  ...       0.0      0.0
# 10994  West North Central        2     1.0     10.0  ...       0.0      0.0
# 42     East North Central        4     1.0     10.0  ...       9.0      0.0
# 9375   East North Central        2     1.0     10.0  ...       0.0      0.0
# 4684   East North Central        2     0.0     10.0  ...       0.0      0.0
# 4629   West North Central        2     1.0     10.0  ...       9.0      0.0
# 2328   East North Central        4     1.0     10.0  ...       9.0      0.0
# 15843  East North Central        2     1.0     10.0  ...       0.0      0.0
# 11258  East North Central        2     0.0     20.0  ...       0.0      0.0
# 3378   West North Central        2     1.0     10.0  ...       9.0      0.0
# 19966  East North Central        3     0.0     10.0  ...       0.0      0.0
# 15890  West North Central        2     1.0     10.0  ...       0.0      0.0
# 7935   West North Central        2     1.0     10.0  ...       0.0      0.0
# 11944  West North Central        2     1.0     10.0  ...       0.0      0.0
# 12066  West North Central        2     1.0     20.0  ...       0.0      0.0
# 18700  West North Central        3     1.0     20.0  ...       0.0      0.0
# 19398  West North Central        1     1.0     10.0  ...       0.0      0.0
# 16887  West North Central        3     1.0     10.0  ...       0.0      0.0
# 5306   West North Central        2     1.0     10.0  ...       0.0      0.0
# 12202  West North Central        2     1.0     10.0  ...       0.0      0.0
# 15408  East North Central        2     1.0     10.0  ...       0.0      0.0
# 6224   West North Central        2     1.0     10.0  ...       0.0      0.0
#
#        WDWARM  WDWATER  USESOLAR  SOLWATER  SOLOTHER  TVAUDIOEQUIP  \
# 4371        0        0         0         0         0             7
# 5223        0        0         0         0         0             7
# 10554       0        0         0         0         0             5
# 18167       0        0         0         0         0             5
# 2193        0        0         0         0         0            10
# 8451        1        0         0         0         0             8
# 12015       0        0         0         0         0            13
# 12875       0        0         0         0         0            10
# 20455       0        0         0         0         0             5
# 10994       0        0         1         0         1            13
# 42          0        0         0         0         0             2
# 9375        0        0         0         0         0            13
# 4684        0        0         0         0         0            12
# 4629        0        0         0         0         0             4
# 2328        0        0         0         0         0             6
# 15843       0        0         0         0         0             6
# 11258       0        0         0         0         0             9
# 3378        0        0         0         0         0             7
# 19966       0        0         0         0         0            10
# 15890       0        0         0         0         0             5
# 7935        0        0         0         0         0             6
# 11944       0        0         0         0         0             8
# 12066       0        0         0         0         0             7
# 18700       0        0         0         0         0            16
# 19398       0        0         0         0         0             3
# 16887       0        0         0         0         0             2
# 5306        0        0         0         0         0             4
# 12202       0        0         0         0         0            12
# 15408       0        0         0         0         0             9
# 6224        1        0         0         0         0            12
#
#        PCOFFEQUIP  PHONE
# 4371            4      2
# 5223            3      0
# 10554           2      0
# 18167           0      1
# 2193            3      3
# 8451            4      1
# 12015           3      2
# 12875           3      2
# 20455           2      1
# 10994           4      0
# 42              0      1
# 9375            0      0
# 4684            2      0
# 4629            0      0
# 2328            2      1
# 15843           5      2
# 11258           4      2
# 3378            0      1
# 19966           2      4
# 15890           0      2
# 7935            3      2
# 11944           3      0
# 12066           4      2
# 18700           8      2
# 19398           4      2
# 16887           1      1
# 5306            7      0
# 12202           6      0
# 15408           1      2
# 6224            0      1
#
# [30 rows x 196 columns]
#  X Features shape : (30, 87)
# y label shape : (30,)
# shape of X is (30, 79)

# %%
# pd.DataFrame(X,columns = vocab).to_csv(os.path.join("dataforfinalproject/InputSamples.csv"), index = True)

# %%
# df_recs = pd.read_csv(os.path.join(dataFilePath, filename), low_memory= False)


# df_recs[(eval(totsqt[3]))]

# df_recs[(df_recs.REGIONC == 2) & (eval(totsqt[3]))].sample( n = 10)

# %%
y
# Out:
# 4371     1942.00
# 5223     2229.00
# 10554    1718.00
# 18167    1250.69
# 2193     1817.00
# 8451     1962.00
# 12015    3399.00
# 12875    2702.00
# 20455    1677.05
# 10994    1507.00
# 42        994.00
# 9375     2909.00
# 4684     1872.00
# 4629     1177.00
# 2328     1503.00
# 15843    2470.00
# 11258    1659.00
# 3378      948.00
# 19966    1202.40
# 15890    2256.00
# 7935     2349.00
# 11944    2174.00
# 12066    2317.00
# 18700    1572.54
# 19398    2072.08
# 16887    1767.53
# 5306     1624.00
# 12202    2169.00
# 15408    2518.00
# 6224     1416.00
# Name: TOTALDOLLAR, dtype: float64

# %%
# load the model into a list
model_name = ["Classic Lasso","Elasticnet", "LassoCV", "LR","RF", "RidgeCV","XGB"]
models = [joblib.load(os.path.join("final_models",file)) for file in os.listdir("final_models") if file.endswith("sav")]

# %%
models
# Out:
# [Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#     normalize=False, positive=False, precompute=False, random_state=None,
#     selection='cyclic', tol=0.0001, warm_start=False),
#  ElasticNet(alpha=0.003, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#        max_iter=1000, normalize=False, positive=False, precompute=False,
#        random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#  LassoCV(alphas=None, copy_X=True, cv=10, eps=0.001, fit_intercept=True,
#      max_iter=100000, n_alphas=100, n_jobs=None, normalize=True,
#      positive=False, precompute='auto', random_state=None,
#      selection='cyclic', tol=0.0001, verbose=False),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#           normalize=False),
#  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=11,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=30, verbose=0, warm_start=False),
#  RidgeCV(alphas=array([0.   , 0.003, 0.006, 0.009, 0.012, 0.015, 0.018, 0.021, 0.024,
#         0.027, 0.03 , 0.033, 0.036, 0.039, 0.042, 0.045, 0.048]),
#      cv=30, fit_intercept=True, gcv_mode=None, normalize=True, scoring=None,
#      store_cv_values=False),
#  XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#         colsample_bytree=0.9, gamma=0, importance_type='gain',
#         learning_rate=0.05, max_delta_step=0, max_depth=8,
#         min_child_weight=5, missing=nan, n_estimators=300, n_jobs=1,
#         nthread=2, objective='reg:linear', random_state=0, reg_alpha=0,
#         reg_lambda=1, scale_pos_weight=1, seed=42, silent=1, subsample=0.7)]

# %%
X
# Out:
# array([[ 1.,  1.,  4., ...,  0.,  3., 12.],
#        [ 3., 41.,  3., ...,  1.,  3.,  2.],
#        [ 4.,  3.,  3., ...,  1.,  2.,  1.],
#        ...,
#        [ 1.,  1.,  2., ...,  1.,  3.,  6.],
#        [ 2.,  3., 41., ...,  1., 41.,  1.],
#        [ 2.,  5.,  3., ...,  3.,  3.,  5.]])

# %%
results_data = pd.DataFrame(columns = ["Actual"])
results_score = pd.DataFrame(columns = ["Model","R2", "RMSE"])

results_data['Actual'] = y
results_data
# Out:
#         Actual
# 4371   1942.00
# 5223   2229.00
# 10554  1718.00
# 18167  1250.69
# 2193   1817.00
# 8451   1962.00
# 12015  3399.00
# 12875  2702.00
# 20455  1677.05
# 10994  1507.00
# 42      994.00
# 9375   2909.00
# 4684   1872.00
# 4629   1177.00
# 2328   1503.00
# 15843  2470.00
# 11258  1659.00
# 3378    948.00
# 19966  1202.40
# 15890  2256.00
# 7935   2349.00
# 11944  2174.00
# 12066  2317.00
# 18700  1572.54
# 19398  2072.08
# 16887  1767.53
# 5306   1624.00
# 12202  2169.00
# 15408  2518.00
# 6224   1416.00

# %%
# models[0].predict(X.values)
models[0].predict(X)
# Out:
# array([1734.48845224, 2588.55562357, 1967.01826172, 1398.00354016,
#        2230.23005098, 2170.13064817, 3568.77213409, 2878.77678929,
#        1742.04922882, 1969.3445831 ,  811.71899881, 2675.32073964,
#        1898.27725338, 1086.67348923, 1660.29541331, 2413.65911024,
#        2171.72896415, 1056.83314705, 1654.53278874, 2100.33371531,
#        2315.53584768, 2737.00104624, 2613.23377472, 1946.42358825,
#        2345.72650347, 1796.96773359, 1670.05601333, 2764.71444423,
#        2635.08575973, 1805.76757352])

# %%
for i, model in enumerate(models):
    print(model_name[i])
#     print(X.iloc[0,:])
    pred_price = model.predict(X)
    r2 = round(model.score(X, y)*100,2)
    rmse = round(np.sqrt(mean_squared_error(y,pred_price)))
    
    print(f"Predicted Price is {pred_price}")
    print(f"R2 value is {r2}")
    
    results_data[model_name[i]] = pred_price
    
    results_score['Model'] = model_name[i]
    results_score['R2'] = r2
    results_score['RMSE'] = rmse
# Out:
# Classic Lasso
# Predicted Price is [1734.48845224 2588.55562357 1967.01826172 1398.00354016 2230.23005098
#  2170.13064817 3568.77213409 2878.77678929 1742.04922882 1969.3445831
#   811.71899881 2675.32073964 1898.27725338 1086.67348923 1660.29541331
#  2413.65911024 2171.72896415 1056.83314705 1654.53278874 2100.33371531
#  2315.53584768 2737.00104624 2613.23377472 1946.42358825 2345.72650347
#  1796.96773359 1670.05601333 2764.71444423 2635.08575973 1805.76757352]
# R2 value is 73.36
# Elasticnet
# Predicted Price is [1735.08264276 2587.06249633 1966.62953425 1398.96782468 2229.97432283
#  2170.22579165 3573.47793428 2878.34095181 1741.72904649 1967.05308866
#   812.75052881 2675.71937011 1899.05170491 1085.8806736  1660.99701559
#  2418.03144404 2174.00497874 1055.69608346 1655.23578309 2099.61684685
#  2315.19461985 2736.89628831 2607.04402314 1946.18643256 2345.71319587
#  1796.49838893 1670.00141114 2765.08719938 2634.73415558 1804.02199555]
# R2 value is 73.41
# LassoCV
# Predicted Price is [1741.21700328 2586.86085999 1965.53610223 1397.36481923 2192.24791548
#  2178.10020224 3549.0232081  2843.47438884 1748.25925282 1988.52859494
#   799.02306409 2673.27940021 1898.65227106 1086.47491204 1637.59728399
#  2403.16403254 2159.45755826 1049.24007412 1640.9941954  2072.67681714
#  2312.64987176 2739.68993423 2597.71032681 1967.58531574 2359.46047742
#  1794.5307882  1673.57302266 2747.4208911  2614.26406488 1802.72652945]
# R2 value is 73.94
# LR
# Predicted Price is [1734.40049624 2588.48431676 1967.00591343 1397.9171391  2230.19772583
#  2169.98613063 3568.64372892 2879.14326878 1741.98411667 1969.86879608
#   811.73856098 2675.29264826 1898.31150916 1086.75257004 1660.30903069
#  2413.56233613 2171.74623295 1056.94530473 1654.36985729 2100.44063216
#  2315.5818845  2736.92577506 2613.43181413 1946.49782918 2345.63268133
#  1797.11999483 1669.87949823 2764.70003303 2635.19911549 1806.0043704 ]
# R2 value is 73.36
# RF
# Predicted Price is [1602.05954958 2241.01788016 1715.83211525 1244.73319101 1948.16333673
#  1936.62584329 3174.07133758 2498.86983008 1712.84678088 1975.25849407
#   768.73157929 2703.40609097 1757.19872699 1210.51000383 1499.77233515
#  2201.97585943 1874.67658542 1177.99873154 1520.97520978 1960.73622491
#  2127.60126075 2501.23675167 2638.74840457 2028.8139108  2186.01617269
#  1705.40889222 1507.48335523 2541.1967748  2134.12486178 1815.64427825]
# R2 value is 80.37
# RidgeCV
# Predicted Price is [1734.40049624 2588.48431676 1967.00591343 1397.9171391  2230.19772583
#  2169.98613063 3568.64372892 2879.14326878 1741.98411667 1969.86879608
#   811.73856098 2675.29264826 1898.31150916 1086.75257004 1660.30903069
#  2413.56233613 2171.74623295 1056.94530473 1654.36985729 2100.44063216
#  2315.5818845  2736.92577506 2613.43181413 1946.49782918 2345.63268133
#  1797.11999483 1669.87949823 2764.70003303 2635.19911549 1806.0043704 ]
# R2 value is 73.36
# XGB
# Predicted Price is [1712.9147  2364.6812  1738.7084  1211.4088  1902.1438  1963.9725
#  3354.7598  2696.0457  1709.4044  1606.445    800.2277  2791.9263
#  1728.5259  1127.9795  1444.8022  2467.1282  1933.6626  1017.22955
#  1337.1654  2237.4167  2278.902   2411.6094  2404.1438  1669.4
#  2238.4963  1674.5547  1571.2362  2392.5183  2475.2153  1584.6783 ]
# R2 value is 95.06

# %%
results_data.to_csv("dataforfinalproject/resultsdata.csv", index = True)

# %%
results_data
# Out:
#         Actual  Classic Lasso   Elasticnet      LassoCV           LR  \
# 4371   1942.00    1734.488452  1735.082643  1741.217003  1734.400496
# 5223   2229.00    2588.555624  2587.062496  2586.860860  2588.484317
# 10554  1718.00    1967.018262  1966.629534  1965.536102  1967.005913
# 18167  1250.69    1398.003540  1398.967825  1397.364819  1397.917139
# 2193   1817.00    2230.230051  2229.974323  2192.247915  2230.197726
# 8451   1962.00    2170.130648  2170.225792  2178.100202  2169.986131
# 12015  3399.00    3568.772134  3573.477934  3549.023208  3568.643729
# 12875  2702.00    2878.776789  2878.340952  2843.474389  2879.143269
# 20455  1677.05    1742.049229  1741.729046  1748.259253  1741.984117
# 10994  1507.00    1969.344583  1967.053089  1988.528595  1969.868796
# 42      994.00     811.718999   812.750529   799.023064   811.738561
# 9375   2909.00    2675.320740  2675.719370  2673.279400  2675.292648
# 4684   1872.00    1898.277253  1899.051705  1898.652271  1898.311509
# 4629   1177.00    1086.673489  1085.880674  1086.474912  1086.752570
# 2328   1503.00    1660.295413  1660.997016  1637.597284  1660.309031
# 15843  2470.00    2413.659110  2418.031444  2403.164033  2413.562336
# 11258  1659.00    2171.728964  2174.004979  2159.457558  2171.746233
# 3378    948.00    1056.833147  1055.696083  1049.240074  1056.945305
# 19966  1202.40    1654.532789  1655.235783  1640.994195  1654.369857
# 15890  2256.00    2100.333715  2099.616847  2072.676817  2100.440632
# 7935   2349.00    2315.535848  2315.194620  2312.649872  2315.581884
# 11944  2174.00    2737.001046  2736.896288  2739.689934  2736.925775
# 12066  2317.00    2613.233775  2607.044023  2597.710327  2613.431814
# 18700  1572.54    1946.423588  1946.186433  1967.585316  1946.497829
# 19398  2072.08    2345.726503  2345.713196  2359.460477  2345.632681
# 16887  1767.53    1796.967734  1796.498389  1794.530788  1797.119995
# 5306   1624.00    1670.056013  1670.001411  1673.573023  1669.879498
# 12202  2169.00    2764.714444  2765.087199  2747.420891  2764.700033
# 15408  2518.00    2635.085760  2634.734156  2614.264065  2635.199115
# 6224   1416.00    1805.767574  1804.021996  1802.726529  1806.004370
#
#                 RF      RidgeCV          XGB
# 4371   1602.059550  1734.400496  1712.914673
# 5223   2241.017880  2588.484317  2364.681152
# 10554  1715.832115  1967.005913  1738.708374
# 18167  1244.733191  1397.917139  1211.408813
# 2193   1948.163337  2230.197726  1902.143799
# 8451   1936.625843  2169.986131  1963.972534
# 12015  3174.071338  3568.643729  3354.759766
# 12875  2498.869830  2879.143269  2696.045654
# 20455  1712.846781  1741.984117  1709.404419
# 10994  1975.258494  1969.868796  1606.444946
# 42      768.731579   811.738561   800.227722
# 9375   2703.406091  2675.292648  2791.926270
# 4684   1757.198727  1898.311509  1728.525879
# 4629   1210.510004  1086.752570  1127.979492
# 2328   1499.772335  1660.309031  1444.802246
# 15843  2201.975859  2413.562336  2467.128174
# 11258  1874.676585  2171.746233  1933.662598
# 3378   1177.998732  1056.945305  1017.229553
# 19966  1520.975210  1654.369857  1337.165405
# 15890  1960.736225  2100.440632  2237.416748
# 7935   2127.601261  2315.581884  2278.902100
# 11944  2501.236752  2736.925775  2411.609375
# 12066  2638.748405  2613.431814  2404.143799
# 18700  2028.813911  1946.497829  1669.400024
# 19398  2186.016173  2345.632681  2238.496338
# 16887  1705.408892  1797.119995  1674.554688
# 5306   1507.483355  1669.879498  1571.236206
# 12202  2541.196775  2764.700033  2392.518311
# 15408  2134.124862  2635.199115  2475.215332
# 6224   1815.644278  1806.004370  1584.678345

# %%
results1 = pd.DataFrame(results_data.stack(), columns = ["Price"])

# %%
results1.reset_index(inplace = True)

# %%
# results1.drop("level_0", axis = 1, inplace = True)

# %%
results1.columns = ['SampleNum','Model','Price']

# %%
results1.head()
# Out:
#    SampleNum          Model        Price
# 0       4371         Actual  1942.000000
# 1       4371  Classic Lasso  1734.488452
# 2       4371     Elasticnet  1735.082643
# 3       4371        LassoCV  1741.217003
# 4       4371             LR  1734.400496

# %%
results1.to_csv("dataforfinalproject/resultsdata_1.csv")

# %%
fig, ax = plt.subplots(figsize = (20, 20))
sns.scatterplot(x = "SampleNum", y = "Price", data = results1, hue = results1.Model, ax = ax, style = "Model", s = 150, palette = "gist_rainbow")
plt.legend(loc = "best")
plt.ylim(min(results1.Price)-60, max(results1.Price)+60)
plt.show()

# %%
# fig, ax1 = plt.subplots(figsize = (12, 8))
g = sns.catplot(x = "SampleNum", y = "Price",hue = "Model",  data = results1, height=6, kind="bar", palette="muted")

g.despine(left=True)
g.set_ylabels("Predicted vs actual Price")

# %%
df_recs = pd.read_csv(os.path.join(dataFilePath, filename), low_memory= False)

# %%
totsqt = {0 : "df_recs.TOTHSQFT != -1",
             1 : "df_recs.TOTHSQFT < 900",
             2 : "df_recs.TOTHSQFT >= 900"}

# %%
print(totsqt[2])
# Out:
# df_recs.TOTHSQFT >= 900

# %%
df = df_recs[eval(totsqt[0])]
df.shape
# Out:
# (10, 196)
