# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os 
from generateXdata import generateX

# Load in csv

#raw_df = pd.read_csv("C:/Users/admin/Documents/SMU/Final Project/Data/recs2015.csv")
filepath = os.path.join("dataforfinalproject","RECS_COMBINED_DATA.csv")
raw_df=pd.read_csv(filepath)
colmns_file = os.path.join("dataforfinalproject","Final_Columns_withCat.csv")
cols_file=pd.read_csv(colmns_file)

# %%
# read the columns from Columns csv
df_cols = pd.read_csv(colmns_file)
df_cols
# df_cols.columns
# Out:
#       COLUMN_NAME COLUMN_CAT_ABBR                     COLUMN_CATEGORY  \
# 0        RECSYEAR          COMMON                     CommonVariables
# 1         COUNTRY          COMMON                     CommonVariables
# 2           DOEID          COMMON                     CommonVariables
# 3         REGIONC          COMMON                     CommonVariables
# 4        DIVISION          COMMON                     CommonVariables
# 5         TYPEHUQ          COMMON                     CommonVariables
# 6          CELLAR             HUC        Housing Unit Characteristics
# 7         STORIES             HUC        Housing Unit Characteristics
# 8        PRKGPLC1             HUC        Housing Unit Characteristics
# 9        YEARMADE             HUC        Housing Unit Characteristics
# 10        OCCUPYY             HUC        Housing Unit Characteristics
# 11       BEDROOMS             HUC        Housing Unit Characteristics
# 12       NCOMBATH             HUC        Housing Unit Characteristics
# 13       NHAFBATH             HUC        Housing Unit Characteristics
# 14       OTHROOMS             HUC        Housing Unit Characteristics
# 15       TOTROOMS             HUC        Housing Unit Characteristics
# 16       DOOR1SUM             WTH  Water heating, Cooling and Miscell
# 17        WINDOWS             WTH  Water heating, Cooling and Miscell
# 18       ADQINSUL             WTH  Water heating, Cooling and Miscell
# 19         DRAFTY             WTH  Water heating, Cooling and Miscell
# 20       UGASHERE             HUC        Housing Unit Characteristics
# 21       FUELPOOL         APL_OTH                    Other Appliances
# 22       SIZRFRI1         APL_KIT                  Kitchen Appliances
# 23       TYPERFR1         APL_KIT                  Kitchen Appliances
# 24       AGERFRI1         APL_KIT                  Kitchen Appliances
# 25            ICE         APL_KIT                  Kitchen Appliances
# 26       SIZRFRI2         APL_KIT                  Kitchen Appliances
# 27       TYPERFR2         APL_KIT                  Kitchen Appliances
# 28       AGERFRI2         APL_KIT                  Kitchen Appliances
# 29       NUMFREEZ         APL_KIT                  Kitchen Appliances
# ..            ...             ...                                 ...
# 170       AIRCOND             WTH  Water heating, Cooling and Miscell
# 171       CENACHP             WTH  Water heating, Cooling and Miscell
# 172         USEEL             FUP         Fuels Used and Fuel Payment
# 173        ELWARM             FUP         Fuels Used and Fuel Payment
# 174        ELCOOL             FUP         Fuels Used and Fuel Payment
# 175        ELFOOD             FUP         Fuels Used and Fuel Payment
# 176       ELOTHER             FUP         Fuels Used and Fuel Payment
# 177        UGWARM             FUP         Fuels Used and Fuel Payment
# 178       UGWATER             FUP         Fuels Used and Fuel Payment
# 179        UGCOOK             FUP         Fuels Used and Fuel Payment
# 180         UGOTH             FUP         Fuels Used and Fuel Payment
# 181         USELP             FUP         Fuels Used and Fuel Payment
# 182        LPWARM             FUP         Fuels Used and Fuel Payment
# 183       LPWATER             FUP         Fuels Used and Fuel Payment
# 184        LPCOOK             FUP         Fuels Used and Fuel Payment
# 185         USEFO             FUP         Fuels Used and Fuel Payment
# 186        FOWARM             FUP         Fuels Used and Fuel Payment
# 187       FOWATER             FUP         Fuels Used and Fuel Payment
# 188       USEWOOD             FUP         Fuels Used and Fuel Payment
# 189      WOODLOGS             FUP         Fuels Used and Fuel Payment
# 190      WDPELLET             FUP         Fuels Used and Fuel Payment
# 191       WDOTHER             FUP         Fuels Used and Fuel Payment
# 192        WDWARM             FUP         Fuels Used and Fuel Payment
# 193       WDWATER             FUP         Fuels Used and Fuel Payment
# 194      USESOLAR             FUP         Fuels Used and Fuel Payment
# 195      SOLWATER             FUP         Fuels Used and Fuel Payment
# 196      SOLOTHER             FUP         Fuels Used and Fuel Payment
# 197  TVAUDIOEQUIP         APL_OTH                    Other Appliances
# 198    PCOFFEQUIP         APL_OTH                    Other Appliances
# 199         PHONE         APL_OTH                    Other Appliances
#
#                                     COLUMN_DESCRIPTION FEATURES_MODEL  \
# 0                                Survey Conducted Year              N
# 1                                               String              N
# 2                        4-digit identification number              N
# 3                                        Census Region              Y
# 4                                      Census Division              Y
# 5                Type of Home: as report by Respondent              N
# 6                                    Home Has Basement              Y
# 7                     Reported Stories in Housing Unit              Y
# 8                           Home has Garage or Carport              Y
# 9                                      Year Home Built              Y
# 10                                Year Moved into Home              Y
# 11                                  Number of bedrooms              Y
# 12                            Number of Complete Baths              Y
# 13                                Number of Half Baths              Y
# 14                               Number of Other Rooms              Y
# 15                               Total Number of Rooms              Y
# 16                       Number of sliding glass doors              N
# 17                                   Number of windows              Y
# 18            Respondent perception of home insulation              Y
# 19   How often find your home too drafty during winter              Y
# 20         Natural gas from underground pipe available              N
# 21     What fuel is used most often to heat pool water              Y
# 22                          Size of first refrigerator              Y
# 23                         Type of first refrigerators              Y
# 24                       How old is first refrigerator              Y
# 25         Does refrigerator have through-the-door ice              N
# 26                         Size of second refrigerator              Y
# 27                         Type of second refrigerator              Y
# 28                      How old is second refrigerator              Y
# 29    How many separate freezers are used in your home              Y
# ..                                                 ...            ...
# 170     Do you have air conditioning equipment at home              N
# 171              Is your central AC system a heat pump              N
# 172                                HH uses electricity              N
# 173                          Electricity used for heat              N
# 174                           Electricity used to cool              N
# 175                           Electricity used to cook              N
# 176                         Electricity used for other              N
# 177                          Natural gas used for heat              N
# 178                           Natural gas used for H2O              N
# 179                           Natural gas used to cook              N
# 180                         Natural gas used for other              N
# 181                                        HH uses LPG              N
# 182                          Bottled gas used for heat              N
# 183                           Bottled gas used for H2O              Y
# 184                           Bottled gas used to cook              N
# 185                                   HH uses Fuel oil              N
# 186                             Fuel oil used for heat              N
# 187                              Fuel oil used for H2O              N
# 188                                       HH uses Wood              N
# 189     Use Wood logs or split wood as a fuel in house              N
# 190                Use Wood pellets as a fuel in house              N
# 191                                Wood used for other              N
# 192                                 Wood used for heat              N
# 193                                  Wood used for H2O              N
# 194                                      HH uses solar              N
# 195                                 Solar used for H2O              N
# 196                               Solar used for other              N
# 197     Total of All TV, Audio, Stereo, VCR, DVD etc.,              Y
# 198  Total of Desktop, laptop, printer, fax, copier...              Y
# 199  Total of all phones including smartphone and r...              Y
#
#      COLUMN_TYPE  REQ_ONEHOTENC
# 0      Numerical          False
# 1         String          False
# 2      Numerical          False
# 3    Categorical           True
# 4    Categorical           True
# 5    Categorical           True
# 6    Categorical           True
# 7      Numerical          False
# 8    Categorical           True
# 9    Categorical           True
# 10   Categorical           True
# 11     Numerical          False
# 12     Numerical          False
# 13     Numerical          False
# 14     Numerical          False
# 15     Numerical          False
# 16     Numerical          False
# 17   Categorical           True
# 18   Categorical           True
# 19   Categorical           True
# 20   Categorical           True
# 21   Categorical           True
# 22   Categorical           True
# 23   Categorical           True
# 24   Categorical           True
# 25   Categorical           True
# 26   Categorical           True
# 27   Categorical           True
# 28   Categorical           True
# 29     Numerical          False
# ..           ...            ...
# 170  Categorical           True
# 171  Categorical           True
# 172  Categorical           True
# 173  Categorical           True
# 174  Categorical           True
# 175  Categorical           True
# 176  Categorical           True
# 177  Categorical           True
# 178  Categorical           True
# 179  Categorical           True
# 180  Categorical           True
# 181  Categorical           True
# 182  Categorical           True
# 183  Categorical           True
# 184  Categorical           True
# 185  Categorical           True
# 186  Categorical           True
# 187  Categorical           True
# 188  Categorical           True
# 189  Categorical           True
# 190  Categorical           True
# 191  Categorical           True
# 192  Categorical           True
# 193  Categorical           True
# 194  Categorical           True
# 195  Categorical           True
# 196  Categorical           True
# 197    Numerical          False
# 198    Numerical          False
# 199    Numerical          False
#
# [200 rows x 7 columns]

# %%
raw_df.describe()
# Out:
#            RECSYEAR         DOEID       REGIONC      DIVISION       TYPEHUQ  \
# count  22591.000000  22591.000000  22591.000000  22591.000000  22591.000000
# mean    2008.802576   7195.131247      2.651498      5.382453      2.638484
# std        4.762735   4402.416131      1.045644      2.821670      1.184945
# min     2001.000000      1.000000      1.000000      1.000000      1.000000
# 25%     2009.000000   3330.000000      2.000000      3.000000      2.000000
# 50%     2009.000000   6474.000000      3.000000      5.000000      2.000000
# 75%     2015.000000  11061.000000      3.000000      7.000000      3.000000
# max     2015.000000  15686.000000      4.000000     10.000000      5.000000
#
#              CELLAR       STORIES      PRKGPLC1      YEARMADE       OCCUPYY  \
# count  22591.000000  22591.000000  22591.000000  22591.000000  22591.000000
# mean       0.143199     15.248373      0.475897      4.050640      6.796069
# std        2.250864     20.100299      2.239042      2.246379      1.992055
# min       -2.000000     -2.000000     -2.000000      1.000000      1.000000
# 25%       -2.000000     10.000000      0.000000      2.000000      6.000000
# 50%        0.000000     10.000000      0.000000      4.000000      7.000000
# 75%        1.000000     20.000000      1.000000      6.000000      8.000000
# max        9.000000     99.000000      9.000000     13.000000      9.000000
#
#            ...           WDPELLET       WDOTHER        WDWARM       WDWATER  \
# count      ...       22591.000000  22591.000000  22591.000000  22591.000000
# mean       ...           0.255544     -1.387411      0.114824      0.001284
# std        ...           4.179991      0.927600      0.318817      0.035807
# min        ...          -2.000000     -2.000000      0.000000      0.000000
# 25%        ...          -2.000000     -2.000000      0.000000      0.000000
# 50%        ...          -2.000000     -2.000000      0.000000      0.000000
# 75%        ...           0.000000      0.000000      0.000000      0.000000
# max        ...           9.000000      1.000000      1.000000      1.000000
#
#            USESOLAR      SOLWATER      SOLOTHER  TVAUDIOEQUIP    PCOFFEQUIP  \
# count  22591.000000  22591.000000  22591.000000  22591.000000  22591.000000
# mean       0.010579      0.002523      0.006994      6.695720      2.764110
# std        0.102313      0.050168      0.083339      3.735064      2.343253
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      4.000000      1.000000
# 50%        0.000000      0.000000      0.000000      6.000000      3.000000
# 75%        0.000000      0.000000      0.000000      9.000000      4.000000
# max        1.000000      1.000000      1.000000     43.000000     23.000000
#
#               PHONE
# count  22591.000000
# mean       1.534107
# std        1.120486
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max       10.000000
#
# [8 rows x 189 columns]

# %%
#from sklearn.preprocessing import StandardScaler
#features =raw_df[[']]

# %% [markdown]
# # Data Preparation

# %%
# Extract features and labels

labels = raw_df['TOTALDOLLAR']
#raw_df = features.drop('TYPEHUQ', axis = 1)

# %%
# List of features for later use

#model = df_cols[df_cols.FEATURES_MODEL == "Y"].COLUMN_NAME
#modelDF=model.drop(columns=['TOTALBTU'])

#feature=modelDF
#print(modelDF)
#features = list(features.columns)

# %%
# Convert to numpy array
features_X,columns_names = generateX()
# Out:
#  X Features shape : (22591, 87)
# cols with values as 99 and -2: ['CELLAR', 'STORIES', 'PRKGPLC1', 'BEDROOMS', 'FUELPOOL', 'SIZRFRI1', 'TYPERFR1', 'AGERFRI1', 'SIZRFRI2', 'TYPERFR2', 'AGERFRI2', 'NUMFREEZ', 'SIZFREEZ', 'AGEFRZR', 'STOVENFUEL', 'OVENUSE', 'AMTMICRO', 'DWASHUSE', 'WASHLOAD', 'WASHTEMP', 'EQUIPM', 'FUELHEAT', 'EQUIPAGE', 'PROTHERM', 'TEMPHOME', 'TEMPGONE', 'TEMPNITE', 'AGECENAC', 'USECENAC', 'NUMBERAC', 'WWACAGE', 'USEWWAC', 'FUELH2O', 'WHEATAGE', 'WHEATSIZ', 'LGTOUTNUM', 'ESDISHW', 'PGASHEAT', 'WOODAMT']
#
# Duplicate Count : 0
# shape of X is (22591, 79)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features_X, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (16943, 79)
# Training Labels Shape: (16943,)
# Testing Features Shape: (5648, 79)
# Testing Labels Shape: (5648,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 10 decision trees

rf = RandomForestRegressor(n_estimators = 50, random_state = 42, max_depth = 11)

# Train the model on training data
rf.fit(train_features, train_labels);
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# Import the model we are using (modifying model to fit)
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 10 decision trees

rf = RandomForestRegressor(n_estimators = 50, random_state = 42, max_depth = 10)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
from sklearn.metrics import mean_squared_error
predictions = rf.predict(test_features)
MSE = mean_squared_error(test_labels, predictions)

r2 = rf.score(test_features, test_labels)
print(MSE)
print(r2)
# Out:
# 304664.2681455089
# 0.762360551559701

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf.feature_importances_
importances
# Out:
# array([7.76581932e-04, 5.43475039e-04, 3.55261766e-04, 6.30395601e-04,
#        4.71000669e-04, 9.78320582e-04, 1.25115399e-03, 4.17835103e-02,
#        3.04110034e-02, 4.99182565e-01, 5.85751653e-03, 3.49598264e-03,
#        2.74036263e-03, 5.02403909e-02, 3.78657481e-03, 4.29143421e-04,
#        6.96458494e-02, 5.19699023e-02, 4.41454830e-04, 6.59648033e-04,
#        7.89341108e-05, 3.48707264e-04, 5.83641837e-04, 1.18636214e-03,
#        3.32230550e-04, 2.89491111e-04, 3.20148343e-03, 1.70044449e-04,
#        3.14411128e-02, 7.93510142e-03, 1.51810306e-03, 1.98165168e-04,
#        2.56079576e-04, 1.62187862e-03, 1.88328203e-04, 3.88525535e-03,
#        1.93373829e-03, 1.73738738e-03, 2.18319127e-03, 8.78258482e-04,
#        1.33581523e-03, 3.90933022e-04, 8.67679664e-04, 5.48756872e-04,
#        6.81640434e-04, 5.41293602e-04, 8.26299214e-04, 1.37853738e-03,
#        2.05947790e-03, 5.61174196e-04, 2.92471283e-04, 1.96868166e-04,
#        3.14736056e-04, 3.81030949e-02, 5.35067368e-04, 4.43514871e-04,
#        4.03937664e-04, 2.25775853e-04, 5.19821200e-04, 9.67549079e-04,
#        7.74173206e-04, 1.22993440e-03, 3.23890266e-03, 3.73470722e-03,
#        1.28018741e-03, 1.41715993e-03, 2.44778406e-03, 2.21009131e-03,
#        5.11193512e-04, 5.43030568e-04, 1.61886893e-04, 9.82275916e-04,
#        6.08191595e-04, 5.22830005e-04, 3.01487174e-04, 1.01715679e-01,
#        3.08744682e-04, 3.22387760e-04, 8.77320270e-04])

# %%
# We can sort the features by their importance
df=pd.DataFrame(sorted(zip(rf.feature_importances_,columns_names), reverse=True))
print(df)
# Out:
#            0                 1
# 0   0.499183          BTUELOTH
# 1   0.101716           WINDOWS
# 2   0.069646          CUFEETNG
# 3   0.051970          DIVISION
# 4   0.050240             BTUFO
# 5   0.041784             BTUEL
# 6   0.038103           REGIONC
# 7   0.031441          GALLONLP
# 8   0.030411          BTUELCOL
# 9   0.007935             HDD65
# 10  0.005858          BTUELRFG
# 11  0.003885           MONEYPY
# 12  0.003787             CDD65
# 13  0.003735          TOTHSQFT
# 14  0.003496          BTUELSPH
# 15  0.003239          TOTCSQFT
# 16  0.003201          FUELHEAT
# 17  0.002740          BTUELWTH
# 18  0.002448      TVAUDIOEQUIP
# 19  0.002210          TYPERFR1
# 20  0.002183          NHSLDMEM
# 21  0.002059          PGASHEAT
# 22  0.001934          NCOMBATH
# 23  0.001737          NHAFBATH
# 24  0.001622         LGTOUTNUM
# 25  0.001518             HHAGE
# 26  0.001417          TOTUSQFT
# 27  0.001379        PCOFFEQUIP
# 28  0.001336           NUMCFAN
# 29  0.001280          TOTROOMS
# ..       ...               ...
# 49  0.000543          AGECENAC
# 50  0.000543          USECENAC
# 51  0.000541          OTHROOMS
# 52  0.000535          SIZFREEZ
# 53  0.000523          WHEATAGE
# 54  0.000520        STOVENFUEL
# 55  0.000511          TYPERFR2
# 56  0.000471          AGERFRI2
# 57  0.000444          SIZRFRI1
# 58  0.000441            DRAFTY
# 59  0.000429            CELLAR
# 60  0.000404          SIZRFRI2
# 61  0.000391          NUMFREEZ
# 62  0.000355           AGEFRZR
# 63  0.000349          EMPLOYHH
# 64  0.000332           ESDISHW
# 65  0.000322           WWACAGE
# 66  0.000315           RECBATH
# 67  0.000309           WOODAMT
# 68  0.000301          WHEATSIZ
# 69  0.000292          PRKGPLC1
# 70  0.000289           FUELH2O
# 71  0.000256  HOUSEHOLDER_RACE
# 72  0.000226           STORIES
# 73  0.000198             HHSEX
# 74  0.000197          PROTHERM
# 75  0.000188           LPWATER
# 76  0.000170          FUELPOOL
# 77  0.000162           USEWWAC
# 78  0.000079           ELECAUX
#
# [79 rows x 2 columns]

# %%
g = sns.pairplot(raw_df,
x_vars=["TOTALDOLLAR"],
y_vars=['BTUELOTH','WINDOWS', 'TOTHSQFT','CUFEETNG','BTUFO','BTUEL','REGIONC','GALLONLP','BTUELCOL','HDD65','BTUELRFG'])
g.map(plt.scatter, alpha=0.5)
g.add_legend();
plt.savefig('C:/Users/admin/Desktop/Project3final/Pictures/RandomForestTotalDollar.png')
