# %%
# Dependencies
import matplotlib.pyplot as plt

# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os 
from generateXdata import generateX
from math import ceil
import warnings
# Load in csv

#raw_df = pd.read_csv("C:/Users/admin/Documents/SMU/Final Project/Data/recs2015.csv")
filepath = os.path.join("dataforfinalproject","RECS_COMBINED_DATA.csv")
raw_df=pd.read_csv(filepath)
colmns_file = os.path.join("dataforfinalproject","Final_Columns_withCat.csv")
cols_file=pd.read_csv(colmns_file)

# %%
# read the columns from Columns csv
df_cols = pd.read_csv(colmns_file)
df_cols
# df_cols.columns
# Out:
#       COLUMN_NAME COLUMN_CAT_ABBR                     COLUMN_CATEGORY  \
# 0        RECSYEAR          COMMON                     CommonVariables
# 1         COUNTRY          COMMON                     CommonVariables
# 2           DOEID          COMMON                     CommonVariables
# 3         REGIONC          COMMON                     CommonVariables
# 4      REGIONNAME          COMMON                     CommonVariables
# 5        DIVISION          COMMON                     CommonVariables
# 6    DIVISIONNAME          COMMON                     CommonVariables
# 7         TYPEHUQ          COMMON                     CommonVariables
# 8          CELLAR             HUC        Housing Unit Characteristics
# 9         STORIES             HUC        Housing Unit Characteristics
# 10       PRKGPLC1             HUC        Housing Unit Characteristics
# 11       YEARMADE             HUC        Housing Unit Characteristics
# 12        OCCUPYY             HUC        Housing Unit Characteristics
# 13       BEDROOMS             HUC        Housing Unit Characteristics
# 14       NCOMBATH             HUC        Housing Unit Characteristics
# 15       NHAFBATH             HUC        Housing Unit Characteristics
# 16       OTHROOMS             HUC        Housing Unit Characteristics
# 17       TOTROOMS             HUC        Housing Unit Characteristics
# 18       DOOR1SUM             WTH  Water heating, Cooling and Miscell
# 19        WINDOWS             WTH  Water heating, Cooling and Miscell
# 20       ADQINSUL             WTH  Water heating, Cooling and Miscell
# 21         DRAFTY             WTH  Water heating, Cooling and Miscell
# 22       UGASHERE             HUC        Housing Unit Characteristics
# 23       FUELPOOL         APL_OTH                    Other Appliances
# 24       SIZRFRI1         APL_KIT                  Kitchen Appliances
# 25       TYPERFR1         APL_KIT                  Kitchen Appliances
# 26       AGERFRI1         APL_KIT                  Kitchen Appliances
# 27            ICE         APL_KIT                  Kitchen Appliances
# 28       SIZRFRI2         APL_KIT                  Kitchen Appliances
# 29       TYPERFR2         APL_KIT                  Kitchen Appliances
# ..            ...             ...                                 ...
# 172       AIRCOND             WTH  Water heating, Cooling and Miscell
# 173       CENACHP             WTH  Water heating, Cooling and Miscell
# 174         USEEL             FUP         Fuels Used and Fuel Payment
# 175        ELWARM             FUP         Fuels Used and Fuel Payment
# 176        ELCOOL             FUP         Fuels Used and Fuel Payment
# 177        ELFOOD             FUP         Fuels Used and Fuel Payment
# 178       ELOTHER             FUP         Fuels Used and Fuel Payment
# 179        UGWARM             FUP         Fuels Used and Fuel Payment
# 180       UGWATER             FUP         Fuels Used and Fuel Payment
# 181        UGCOOK             FUP         Fuels Used and Fuel Payment
# 182         UGOTH             FUP         Fuels Used and Fuel Payment
# 183         USELP             FUP         Fuels Used and Fuel Payment
# 184        LPWARM             FUP         Fuels Used and Fuel Payment
# 185       LPWATER             FUP         Fuels Used and Fuel Payment
# 186        LPCOOK             FUP         Fuels Used and Fuel Payment
# 187         USEFO             FUP         Fuels Used and Fuel Payment
# 188        FOWARM             FUP         Fuels Used and Fuel Payment
# 189       FOWATER             FUP         Fuels Used and Fuel Payment
# 190       USEWOOD             FUP         Fuels Used and Fuel Payment
# 191      WOODLOGS             FUP         Fuels Used and Fuel Payment
# 192      WDPELLET             FUP         Fuels Used and Fuel Payment
# 193       WDOTHER             FUP         Fuels Used and Fuel Payment
# 194        WDWARM             FUP         Fuels Used and Fuel Payment
# 195       WDWATER             FUP         Fuels Used and Fuel Payment
# 196      USESOLAR             FUP         Fuels Used and Fuel Payment
# 197      SOLWATER             FUP         Fuels Used and Fuel Payment
# 198      SOLOTHER             FUP         Fuels Used and Fuel Payment
# 199  TVAUDIOEQUIP         APL_OTH                    Other Appliances
# 200    PCOFFEQUIP         APL_OTH                    Other Appliances
# 201         PHONE         APL_OTH                    Other Appliances
#
#                                     COLUMN_DESCRIPTION FEATURES_MODEL  \
# 0                                Survey Conducted Year              N
# 1                                               String              N
# 2                        4-digit identification number              N
# 3                                        Census Region              Y
# 4                                          Region Name              N
# 5                                      Census Division              Y
# 6                                       Division names              N
# 7                Type of Home: as report by Respondent              N
# 8                                    Home Has Basement              Y
# 9                     Reported Stories in Housing Unit              Y
# 10                          Home has Garage or Carport              Y
# 11                                     Year Home Built              Y
# 12                                Year Moved into Home              Y
# 13                                  Number of bedrooms              Y
# 14                            Number of Complete Baths              Y
# 15                                Number of Half Baths              Y
# 16                               Number of Other Rooms              Y
# 17                               Total Number of Rooms              Y
# 18                       Number of sliding glass doors              N
# 19                                   Number of windows              Y
# 20            Respondent perception of home insulation              Y
# 21   How often find your home too drafty during winter              Y
# 22         Natural gas from underground pipe available              N
# 23     What fuel is used most often to heat pool water              Y
# 24                          Size of first refrigerator              Y
# 25                         Type of first refrigerators              Y
# 26                       How old is first refrigerator              Y
# 27         Does refrigerator have through-the-door ice              N
# 28                         Size of second refrigerator              Y
# 29                         Type of second refrigerator              Y
# ..                                                 ...            ...
# 172     Do you have air conditioning equipment at home              N
# 173              Is your central AC system a heat pump              N
# 174                                HH uses electricity              N
# 175                          Electricity used for heat              N
# 176                           Electricity used to cool              N
# 177                           Electricity used to cook              N
# 178                         Electricity used for other              N
# 179                          Natural gas used for heat              N
# 180                           Natural gas used for H2O              N
# 181                           Natural gas used to cook              N
# 182                         Natural gas used for other              N
# 183                                        HH uses LPG              N
# 184                          Bottled gas used for heat              N
# 185                           Bottled gas used for H2O              Y
# 186                           Bottled gas used to cook              N
# 187                                   HH uses Fuel oil              N
# 188                             Fuel oil used for heat              N
# 189                              Fuel oil used for H2O              N
# 190                                       HH uses Wood              N
# 191     Use Wood logs or split wood as a fuel in house              N
# 192                Use Wood pellets as a fuel in house              N
# 193                                Wood used for other              N
# 194                                 Wood used for heat              N
# 195                                  Wood used for H2O              N
# 196                                      HH uses solar              N
# 197                                 Solar used for H2O              N
# 198                               Solar used for other              N
# 199     Total of All TV, Audio, Stereo, VCR, DVD etc.,              Y
# 200  Total of Desktop, laptop, printer, fax, copier...              Y
# 201  Total of all phones including smartphone and r...              Y
#
#      COLUMN_TYPE  REQ_ONEHOTENC
# 0      Numerical          False
# 1         String          False
# 2      Numerical          False
# 3    Categorical           True
# 4    Categorical           True
# 5    Categorical           True
# 6    Categorical           True
# 7    Categorical           True
# 8    Categorical           True
# 9      Numerical          False
# 10   Categorical           True
# 11   Categorical           True
# 12   Categorical           True
# 13     Numerical          False
# 14     Numerical          False
# 15     Numerical          False
# 16     Numerical          False
# 17     Numerical          False
# 18     Numerical          False
# 19   Categorical           True
# 20   Categorical           True
# 21   Categorical           True
# 22   Categorical           True
# 23   Categorical           True
# 24   Categorical           True
# 25   Categorical           True
# 26   Categorical           True
# 27   Categorical           True
# 28   Categorical           True
# 29   Categorical           True
# ..           ...            ...
# 172  Categorical           True
# 173  Categorical           True
# 174  Categorical           True
# 175  Categorical           True
# 176  Categorical           True
# 177  Categorical           True
# 178  Categorical           True
# 179  Categorical           True
# 180  Categorical           True
# 181  Categorical           True
# 182  Categorical           True
# 183  Categorical           True
# 184  Categorical           True
# 185  Categorical           True
# 186  Categorical           True
# 187  Categorical           True
# 188  Categorical           True
# 189  Categorical           True
# 190  Categorical           True
# 191  Categorical           True
# 192  Categorical           True
# 193  Categorical           True
# 194  Categorical           True
# 195  Categorical           True
# 196  Categorical           True
# 197  Categorical           True
# 198  Categorical           True
# 199    Numerical          False
# 200    Numerical          False
# 201    Numerical          False
#
# [202 rows x 7 columns]

# %%
raw_df.describe()
# Out:
#            RECSYEAR         DOEID       REGIONC      DIVISION       TYPEHUQ  \
# count  21430.000000  21430.000000  21430.000000  21430.000000  21430.000000
# mean    2008.789827   7205.857863      2.679888      5.453010      2.666636
# std        4.803271   4406.168345      1.035783      2.806848      1.205252
# min     2001.000000      1.000000      1.000000      1.000000      1.000000
# 25%     2009.000000   3336.250000      2.000000      3.000000      2.000000
# 50%     2009.000000   6481.500000      3.000000      5.000000      2.000000
# 75%     2015.000000  11072.750000      4.000000      8.000000      3.000000
# max     2015.000000  15686.000000      4.000000     10.000000      5.000000
#
#              CELLAR       STORIES      PRKGPLC1      YEARMADE       OCCUPYY  \
# count  21430.000000  21430.000000  21430.000000  21430.000000  21430.000000
# mean       0.126832     15.122912      0.468735      4.062529      6.808166
# std        2.300688     20.558255      2.286153      2.237875      2.003827
# min       -2.000000     -2.000000     -2.000000      1.000000      1.000000
# 25%       -2.000000     10.000000      0.000000      2.000000      6.000000
# 50%        0.000000     10.000000      0.000000      4.000000      8.000000
# 75%        1.000000     20.000000      1.000000      6.000000      8.000000
# max        9.000000     99.000000      9.000000     13.000000      9.000000
#
#            ...           WDPELLET       WDOTHER        WDWARM       WDWATER  \
# count      ...       21430.000000  21430.000000  21430.000000  21430.000000
# mean       ...           0.295194     -1.385768      0.112179      0.001260
# std        ...           4.218022      0.927989      0.315594      0.035474
# min        ...          -2.000000     -2.000000      0.000000      0.000000
# 25%        ...          -2.000000     -2.000000      0.000000      0.000000
# 50%        ...          -2.000000     -2.000000      0.000000      0.000000
# 75%        ...           0.000000      0.000000      0.000000      0.000000
# max        ...           9.000000      1.000000      1.000000      1.000000
#
#            USESOLAR      SOLWATER      SOLOTHER  TVAUDIOEQUIP    PCOFFEQUIP  \
# count  21430.000000  21430.000000  21430.000000  21430.000000  21430.000000
# mean       0.009846      0.002427      0.006300      6.524078      2.665982
# std        0.098740      0.049201      0.079121      3.612805      2.276647
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      4.000000      1.000000
# 50%        0.000000      0.000000      0.000000      6.000000      3.000000
# 75%        0.000000      0.000000      0.000000      9.000000      4.000000
# max        1.000000      1.000000      1.000000     33.000000     23.000000
#
#               PHONE
# count  21430.000000
# mean       1.516472
# std        1.118314
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max       10.000000
#
# [8 rows x 189 columns]

# %%
#from sklearn.preprocessing import StandardScaler
#features =raw_df[[']]

# %% [markdown]
# # Data Preparation

# %%
# Extract features and labels
labels = raw_df['TOTALDOLLAR']
#raw_df = features.drop('TYPEHUQ', axis = 1)

# %%
# List of features for later use

#model = df_cols[df_cols.FEATURES_MODEL == "Y"].COLUMN_NAME
#modelDF=model.drop(columns=['TOTALBTU'])

#feature=modelDF
#print(modelDF)
#features = list(features.columns)

# %%
# Gathering features and columns
features_X,columns_names = generateX(ohe = True, target = "DOLLAR")
# Out:
#  X Features shape : (21430, 87)
# y label shape : (21430,)
# cols with values as 99 and -2: ['CELLAR', 'STORIES', 'PRKGPLC1', 'BEDROOMS', 'FUELPOOL', 'SIZRFRI1', 'TYPERFR1', 'AGERFRI1', 'SIZRFRI2', 'TYPERFR2', 'AGERFRI2', 'NUMFREEZ', 'SIZFREEZ', 'AGEFRZR', 'STOVENFUEL', 'OVENUSE', 'AMTMICRO', 'DWASHUSE', 'WASHLOAD', 'WASHTEMP', 'EQUIPM', 'FUELHEAT', 'EQUIPAGE', 'PROTHERM', 'TEMPHOME', 'TEMPGONE', 'TEMPNITE', 'AGECENAC', 'USECENAC', 'NUMBERAC', 'WWACAGE', 'USEWWAC', 'FUELH2O', 'WHEATAGE', 'WHEATSIZ', 'LGTOUTNUM', 'ESDISHW', 'PGASHEAT', 'WOODAMT']
#
# Duplicate Count : 0
# shape of X is (21430, 79)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features_X, labels, test_size = 0.2, random_state = 30)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (17144, 79)
# Training Labels Shape: (17144,)
# Testing Features Shape: (4286, 79)
# Testing Labels Shape: (4286,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# %%
#Base model 
rf_base = RandomForestRegressor()

# %%
# Final Tuning(n_estimators)

# Instantiate model with 85 decision trees


rf = RandomForestRegressor(n_estimators =85, random_state = 30, max_depth = 11)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
from sklearn.metrics import mean_squared_error
predictions = rf.predict(test_features)
MSE = mean_squared_error(test_labels, predictions)

r2 = rf.score(test_features, test_labels)
print(MSE)
print(r2)
# Out:
# 111694.66018128376
# 0.8239261064838361

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf.feature_importances_
#importances

# %%
# We can sort the features by their importance
df=pd.DataFrame(sorted(zip(rf.feature_importances_,columns_names), reverse=True))
print(df)
# Out:
#            0                 1
# 0   0.271704          TOTHSQFT
# 1   0.132180           WINDOWS
# 2   0.069923          CUFEETNG
# 3   0.042871          GALLONLP
# 4   0.041873          NHSLDMEM
# 5   0.040565          DIVISION
# 6   0.034861          TOTCSQFT
# 7   0.034249           REGIONC
# 8   0.032418      TVAUDIOEQUIP
# 9   0.028834             CDD65
# 10  0.024538          TOTROOMS
# 11  0.019837          BEDROOMS
# 12  0.018500             HDD65
# 13  0.016135           MONEYPY
# 14  0.010531          WASHLOAD
# 15  0.009345             HHAGE
# 16  0.009232          TOTUSQFT
# 17  0.008903          FUELHEAT
# 18  0.008684        PCOFFEQUIP
# 19  0.007767           NUMCFAN
# 20  0.005641          SIZRFRI2
# 21  0.005499          TEMPGONE
# 22  0.005454          SIZFREEZ
# 23  0.005306          TEMPNITE
# 24  0.005001          AMTMICRO
# 25  0.004624          DWASHUSE
# 26  0.004383          TEMPHOME
# 27  0.004293          TYPERFR2
# 28  0.004086          NCOMBATH
# 29  0.003779           OCCUPYY
# ..       ...               ...
# 42  0.002929         LGTOUTNUM
# 43  0.002708          WASHTEMP
# 44  0.002664          NUMBERAC
# 45  0.002637          NUMFREEZ
# 46  0.002491          AGECENAC
# 47  0.002439           FUELH2O
# 48  0.002355          SIZRFRI1
# 49  0.002339             PHONE
# 50  0.002320          WHEATSIZ
# 51  0.002207          PRKGPLC1
# 52  0.002184           RECBATH
# 53  0.001957           WOODAMT
# 54  0.001810            DRAFTY
# 55  0.001803           WWACAGE
# 56  0.001736          USECENAC
# 57  0.001728        STOVENFUEL
# 58  0.001583            CELLAR
# 59  0.001456          ADQINSUL
# 60  0.001416          EMPLOYHH
# 61  0.001292  HOUSEHOLDER_RACE
# 62  0.001259           USEWWAC
# 63  0.001212           STORIES
# 64  0.000993          NHAFBATH
# 65  0.000981           ESDISHW
# 66  0.000910          PROTHERM
# 67  0.000802             HHSEX
# 68  0.000752          PGASHEAT
# 69  0.000543          FUELPOOL
# 70  0.000457           ELECAUX
# 71  0.000358           LPWATER
#
# [72 rows x 2 columns]

# %%
data_plot = raw_df[['BTUELOTH','WINDOWS', 'TOTHSQFT','CUFEETNG','BTUFO','BTUEL','REGIONC','GALLONLP','BTUELCOL','HDD65','BTUELRFG',"TOTALDOLLAR"]]

# %%
fcols = 3
y_vars=['BTUELOTH','WINDOWS', 'TOTHSQFT','CUFEETNG','BTUFO','BTUEL','MONEYPY','GALLONLP','BTUELCOL','HDD65','BTUELRFG']
frows = ceil(len(y_vars)/fcols)
plt.figure(figsize=(15,4*frows))

for i,col in enumerate(y_vars):
    plt.subplot(frows,fcols,i+1)
    sns.violinplot(data_plot[col],data_plot['TOTALDOLLAR'])
#g.map(plt.scatter, alpha=0.5)
#g.add_legend();
#plt.savefig('C:/Users/admin/Desktop/Project3final/Pictures/RandomForestTotalDollar.png')

# %%
#g = sns.pairplot(data_plot)
#g.map(plt.scatter, alpha=0.5)
#g.add_legend();
#plt.savefig('C:/Users/admin/Desktop/Project3final/Pictures/RandomForestTotalDollar.png')
