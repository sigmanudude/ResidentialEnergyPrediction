# %%
import pandas as pd
import numpy as np

import csv
import os

# %%
dataFilePath = "dataforfinalproject"
datafile = "predict_sample.csv"
colfile = "Final_Columns_withCat.csv"

# %%
data_DF = pd.read_csv(os.path.join(dataFilePath, datafile))
df_cols = pd.read_csv(os.path.join(dataFilePath, colfile ), quotechar = '"', quoting = 0)

# %%
data_DF
# Out:
#    RECSYEAR        COUNTRY  DOEID  REGIONC REGIONNAME  DIVISION  \
# 0      2001  United States   1015        1  Northeast         2
# 1      2001  United States   2027        3      South         5
# 2      2009  United States  11041        4       West        10
# 3      2015  United States  15226        2    Midwest         4
# 4      2015  United States  12871        4       West         8
# 5      2001  United States   1001        1  Northeast         1
#
#          DIVISIONNAME  TYPEHUQ  CELLAR  STORIES  ...  WDPELLET  WDOTHER  \
# 0     Middle Atlantic        2       0       20  ...         9        0
# 1      South Atlantic        4       0       10  ...         9        0
# 2             Pacific        2       0       10  ...         0        0
# 3  West North Central        3       0       20  ...        -2       -2
# 4            Mountain        3       1       10  ...        -2       -2
# 5         New England        2       1       31  ...         9        0
#
#    WDWARM  WDWATER  USESOLAR  SOLWATER  SOLOTHER  TVAUDIOEQUIP  PCOFFEQUIP  \
# 0       0        0         0         0         0             5           4
# 1       0        0         0         0         0             2           0
# 2       1        0         0         0         0             6           0
# 3       0        0         0         0         0             6           3
# 4       0        0         0         0         0             7           1
# 5       0        0         0         0         0             8           2
#
#    PHONE
# 0      2
# 1      1
# 2      2
# 3      1
# 4      1
# 5      3
#
# [6 rows x 196 columns]

# %%
keyData = data_DF[df_cols[df_cols.FEATURES_MODEL == "Y"].COLUMN_NAME]
keyData
# Out:
#    REGIONC  DIVISION  CELLAR  STORIES  PRKGPLC1  YEARMADE  OCCUPYY  BEDROOMS  \
# 0        1         2       0       20         1         2        9         4
# 1        3         5       0       10         9         5        1         1
# 2        4        10       0       10         0         1        2         5
# 3        2         4       0       20         0         1        5         3
# 4        4         8       1       10         1         7        7         3
# 5        1         1       1       31         1         9        9         6
#
#    NCOMBATH  NHAFBATH  ...  DOLELOTH   TOTALBTU  TOTALDOLLAR  WOODAMT  \
# 0         1         0  ...   1043.00   96923.00      1885.00        0
# 1         1         0  ...    151.00   25383.00       478.00        0
# 2         2         0  ...    224.11   15644.00       530.00        3
# 3         2         0  ...    711.18   90917.01      1598.29       -2
# 4         3         0  ...   1170.91   98734.79      1996.64       -2
# 5         2         1  ...   1105.00  149495.00      2767.00        0
#
#    RECBATH  NUMFRIG  LPWATER  TVAUDIOEQUIP  PCOFFEQUIP  PHONE
# 0        0        1        0             5           4      2
# 1        0        1        0             2           0      1
# 2        0        1        0             6           0      2
# 3        0        2        0             6           3      1
# 4        0        2        0             7           1      1
# 5        0        1        0             8           2      3
#
# [6 rows x 87 columns]

# %%
# Drop Price / Cost related Columns as it is only Consumption we are interested in 
cost_cols = df_cols[(df_cols['COLUMN_NAME'].str.find("DOL") != -1) & (df_cols.FEATURES_MODEL == "Y")].COLUMN_NAME.tolist()
keyData.drop(cost_cols, axis = 1, inplace = True)

# Also drop the Total BTU cols 
btu_cols = df_cols[(df_cols['COLUMN_NAME'].str.find("TOTALBTU") != -1) & (df_cols.FEATURES_MODEL == "Y")].COLUMN_NAME.tolist()
keyData.drop(btu_cols, axis = 1, inplace = True)
# Out:
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
keyData
# Out:
#    REGIONC  DIVISION  CELLAR  STORIES  PRKGPLC1  YEARMADE  OCCUPYY  BEDROOMS  \
# 0        1         2       0       20         1         2        9         4
# 1        3         5       0       10         9         5        1         1
# 2        4        10       0       10         0         1        2         5
# 3        2         4       0       20         0         1        5         3
# 4        4         8       1       10         1         7        7         3
# 5        1         1       1       31         1         9        9         6
#
#    NCOMBATH  NHAFBATH  ...  BTUELRFG   BTUELOTH  BTUFO  WOODAMT  RECBATH  \
# 0         1         0  ...  3271.000  25874.000  71009        0        0
# 1         1         0  ...  3325.000   5793.000      0        0        0
# 2         2         0  ...  1510.670   6615.650      0        3        0
# 3         2         0  ...  2642.909  17353.910      0       -2        0
# 4         3         0  ...  3686.343  30618.358      0       -2        0
# 5         2         1  ...  5595.000  33750.000      0        0        0
#
#    NUMFRIG  LPWATER  TVAUDIOEQUIP  PCOFFEQUIP  PHONE
# 0        1        0             5           4      2
# 1        1        0             2           0      1
# 2        1        0             6           0      2
# 3        2        0             6           3      1
# 4        2        0             7           1      1
# 5        1        0             8           2      3
#
# [6 rows x 79 columns]

# %%
keyData_new = keyData.T.reset_index()

# %%
df_cols.columns
# Out:
# Index(['COLUMN_NAME', 'COLUMN_CAT_ABBR', 'COLUMN_CATEGORY',
#        'COLUMN_DESCRIPTION', 'FEATURES_MODEL', 'COLUMN_TYPE', 'REQ_ONEHOTENC'],
#       dtype='object')

# %%
keyData_fnl = pd.merge(keyData_new, df_cols[['COLUMN_NAME', 'COLUMN_CATEGORY']], left_on = "index", right_on = "COLUMN_NAME")

# %%
keyData_fnl.drop(['index'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-253fa57d246e> in <module>
# ----> 1 keyData_fnl.drop(['index'], axis = 1, inplace = True)
#       2
#       3 keyData_fnl
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# E:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
keyData_fnl.set_index("COLUMN_NAME", inplace = True)

# %%
keyData_fnl
# Out:
#                         0        1         2          3          4        5  \
# COLUMN_NAME
# REGIONC               1.0      3.0      4.00      2.000      4.000      1.0
# DIVISION              2.0      5.0     10.00      4.000      8.000      1.0
# CELLAR                0.0      0.0      0.00      0.000      1.000      1.0
# STORIES              20.0     10.0     10.00     20.000     10.000     31.0
# PRKGPLC1              1.0      9.0      0.00      0.000      1.000      1.0
# YEARMADE              2.0      5.0      1.00      1.000      7.000      9.0
# OCCUPYY               9.0      1.0      2.00      5.000      7.000      9.0
# BEDROOMS              4.0      1.0      5.00      3.000      3.000      6.0
# NCOMBATH              1.0      1.0      2.00      2.000      3.000      2.0
# NHAFBATH              0.0      0.0      0.00      0.000      0.000      1.0
# BTUFO             71009.0      0.0      0.00      0.000      0.000      0.0
# WOODAMT               0.0      0.0      3.00     -2.000     -2.000      0.0
# RECBATH               0.0      0.0      0.00      0.000      0.000      0.0
# NUMFRIG               1.0      1.0      1.00      2.000      2.000      1.0
# LPWATER               0.0      0.0      0.00      0.000      0.000      0.0
# TVAUDIOEQUIP          5.0      2.0      6.00      6.000      7.000      8.0
# PCOFFEQUIP            4.0      0.0      0.00      3.000      1.000      2.0
# PHONE                 2.0      1.0      2.00      1.000      1.000      3.0
#
#                                      COLUMN_CATEGORY
# COLUMN_NAME
# REGIONC                              CommonVariables
# DIVISION                             CommonVariables
# CELLAR                  Housing Unit Characteristics
# STORIES                 Housing Unit Characteristics
# PRKGPLC1                Housing Unit Characteristics
# YEARMADE                Housing Unit Characteristics
# OCCUPYY                 Housing Unit Characteristics
# BEDROOMS                Housing Unit Characteristics
# NCOMBATH                Housing Unit Characteristics
# NHAFBATH                Housing Unit Characteristics
# OTHROOMS                Housing Unit Characteristics
# TOTROOMS                Housing Unit Characteristics
# WINDOWS           Water heating, Cooling and Miscell
# ADQINSUL          Water heating, Cooling and Miscell
# DRAFTY            Water heating, Cooling and Miscell
# FUELPOOL                            Other Appliances
# SIZRFRI1                          Kitchen Appliances
# TYPERFR1                          Kitchen Appliances
# AGERFRI1                          Kitchen Appliances
# SIZRFRI2                          Kitchen Appliances
# TYPERFR2                          Kitchen Appliances
# AGERFRI2                          Kitchen Appliances
# NUMFREEZ                          Kitchen Appliances
# SIZFREEZ                          Kitchen Appliances
# AGEFRZR                           Kitchen Appliances
# STOVENFUEL                        Kitchen Appliances
# OVENUSE                           Kitchen Appliances
# AMTMICRO                          Kitchen Appliances
# NUMMEAL                           Kitchen Appliances
# DWASHUSE                          Kitchen Appliances
# ...                                              ...
# LGTOUTNUM         Water heating, Cooling and Miscell
# ESDISHW                             Other Appliances
# PGASHEAT                 Fuels Used and Fuel Payment
# HHSEX                      Household Characteristics
# HHAGE                      Household Characteristics
# EMPLOYHH                   Household Characteristics
# HOUSEHOLDER_RACE           Household Characteristics
# NHSLDMEM                   Household Characteristics
# MONEYPY                    Household Characteristics
# TOTCSQFT                Housing Unit Characteristics
# TOTHSQFT                Housing Unit Characteristics
# TOTUSQFT                Housing Unit Characteristics
# CDD65                                CommonVariables
# HDD65                                CommonVariables
# GALLONLP                          Energy Consumption
# CUFEETNG                          Energy Consumption
# BTUEL                             Energy Consumption
# BTUELSPH                          Energy Consumption
# BTUELCOL                          Energy Consumption
# BTUELWTH                          Energy Consumption
# BTUELRFG                          Energy Consumption
# BTUELOTH                          Energy Consumption
# BTUFO                             Energy Consumption
# WOODAMT           Water heating, Cooling and Miscell
# RECBATH                             Other Appliances
# NUMFRIG                           Kitchen Appliances
# LPWATER                  Fuels Used and Fuel Payment
# TVAUDIOEQUIP                        Other Appliances
# PCOFFEQUIP                          Other Appliances
# PHONE                               Other Appliances
#
# [79 rows x 7 columns]
