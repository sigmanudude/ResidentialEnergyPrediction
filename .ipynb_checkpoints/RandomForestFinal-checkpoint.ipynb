# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os 
from generateXdata import generateX

# Load in csv

#raw_df = pd.read_csv("C:/Users/admin/Documents/SMU/Final Project/Data/recs2015.csv")
filepath = os.path.join("dataforfinalproject","RECS_COMBINED_DATA.csv")
raw_df=pd.read_csv(filepath)
colmns_file = os.path.join("dataforfinalproject","Final_Columns_withCat.csv")
cols_file=pd.read_csv(colmns_file)

# %%
# read the columns from Columns csv
df_cols = pd.read_csv(colmns_file)
df_cols
# df_cols.columns
# Out:
#       COLUMN_NAME COLUMN_CAT_ABBR                     COLUMN_CATEGORY  \
# 0        RECSYEAR          COMMON                     CommonVariables
# 1           DOEID          COMMON                     CommonVariables
# 2         REGIONC          COMMON                     CommonVariables
# 3        DIVISION          COMMON                     CommonVariables
# 4         TYPEHUQ          COMMON                     CommonVariables
# 5          CELLAR             HUC        Housing Unit Characteristics
# 6         STORIES             HUC        Housing Unit Characteristics
# 7        PRKGPLC1             HUC        Housing Unit Characteristics
# 8        YEARMADE             HUC        Housing Unit Characteristics
# 9         OCCUPYY             HUC        Housing Unit Characteristics
# 10       BEDROOMS             HUC        Housing Unit Characteristics
# 11       NCOMBATH             HUC        Housing Unit Characteristics
# 12       NHAFBATH             HUC        Housing Unit Characteristics
# 13       OTHROOMS             HUC        Housing Unit Characteristics
# 14       TOTROOMS             HUC        Housing Unit Characteristics
# 15       DOOR1SUM             WTH  Water heating, Cooling and Miscell
# 16        WINDOWS             WTH  Water heating, Cooling and Miscell
# 17       ADQINSUL             WTH  Water heating, Cooling and Miscell
# 18         DRAFTY             WTH  Water heating, Cooling and Miscell
# 19       UGASHERE             HUC        Housing Unit Characteristics
# 20       FUELPOOL         APL_OTH                    Other Appliances
# 21       SIZRFRI1         APL_KIT                  Kitchen Appliances
# 22       TYPERFR1         APL_KIT                  Kitchen Appliances
# 23       AGERFRI1         APL_KIT                  Kitchen Appliances
# 24            ICE         APL_KIT                  Kitchen Appliances
# 25       SIZRFRI2         APL_KIT                  Kitchen Appliances
# 26       TYPERFR2         APL_KIT                  Kitchen Appliances
# 27       AGERFRI2         APL_KIT                  Kitchen Appliances
# 28       NUMFREEZ         APL_KIT                  Kitchen Appliances
# 29       SIZFREEZ         APL_KIT                  Kitchen Appliances
# ..            ...             ...                                 ...
# 169       AIRCOND             WTH  Water heating, Cooling and Miscell
# 170       CENACHP             WTH  Water heating, Cooling and Miscell
# 171         USEEL             FUP         Fuels Used and Fuel Payment
# 172        ELWARM             FUP         Fuels Used and Fuel Payment
# 173        ELCOOL             FUP         Fuels Used and Fuel Payment
# 174        ELFOOD             FUP         Fuels Used and Fuel Payment
# 175       ELOTHER             FUP         Fuels Used and Fuel Payment
# 176        UGWARM             FUP         Fuels Used and Fuel Payment
# 177       UGWATER             FUP         Fuels Used and Fuel Payment
# 178        UGCOOK             FUP         Fuels Used and Fuel Payment
# 179         UGOTH             FUP         Fuels Used and Fuel Payment
# 180         USELP             FUP         Fuels Used and Fuel Payment
# 181        LPWARM             FUP         Fuels Used and Fuel Payment
# 182       LPWATER             FUP         Fuels Used and Fuel Payment
# 183        LPCOOK             FUP         Fuels Used and Fuel Payment
# 184         USEFO             FUP         Fuels Used and Fuel Payment
# 185        FOWARM             FUP         Fuels Used and Fuel Payment
# 186       FOWATER             FUP         Fuels Used and Fuel Payment
# 187       USEWOOD             FUP         Fuels Used and Fuel Payment
# 188      WOODLOGS             FUP         Fuels Used and Fuel Payment
# 189      WDPELLET             FUP         Fuels Used and Fuel Payment
# 190       WDOTHER             FUP         Fuels Used and Fuel Payment
# 191        WDWARM             FUP         Fuels Used and Fuel Payment
# 192       WDWATER             FUP         Fuels Used and Fuel Payment
# 193      USESOLAR             FUP         Fuels Used and Fuel Payment
# 194      SOLWATER             FUP         Fuels Used and Fuel Payment
# 195      SOLOTHER             FUP         Fuels Used and Fuel Payment
# 196  TVAUDIOEQUIP         APL_OTH                    Other Appliances
# 197    PCOFFEQUIP         APL_OTH                    Other Appliances
# 198         PHONE         APL_OTH                    Other Appliances
#
#                                     COLUMN_DESCRIPTION FEATURES_MODEL  \
# 0                                Survey Conducted Year              N
# 1                        4-digit identification number              N
# 2                                        Census Region              Y
# 3                                      Census Division              Y
# 4                Type of Home: as report by Respondent              N
# 5                                    Home Has Basement              Y
# 6                     Reported Stories in Housing Unit              Y
# 7                           Home has Garage or Carport              Y
# 8                                      Year Home Built              Y
# 9                                 Year Moved into Home              Y
# 10                                  Number of bedrooms              Y
# 11                            Number of Complete Baths              Y
# 12                                Number of Half Baths              Y
# 13                               Number of Other Rooms              Y
# 14                               Total Number of Rooms              Y
# 15                       Number of sliding glass doors              N
# 16                                   Number of windows              Y
# 17            Respondent perception of home insulation              Y
# 18   How often find your home too drafty during winter              Y
# 19         Natural gas from underground pipe available              N
# 20     What fuel is used most often to heat pool water              Y
# 21                          Size of first refrigerator              Y
# 22                         Type of first refrigerators              Y
# 23                       How old is first refrigerator              Y
# 24         Does refrigerator have through-the-door ice              N
# 25                         Size of second refrigerator              Y
# 26                         Type of second refrigerator              Y
# 27                      How old is second refrigerator              Y
# 28    How many separate freezers are used in your home              Y
# 29                                Size of this freezer              Y
# ..                                                 ...            ...
# 169     Do you have air conditioning equipment at home              N
# 170              Is your central AC system a heat pump              N
# 171                                HH uses electricity              N
# 172                          Electricity used for heat              N
# 173                           Electricity used to cool              N
# 174                           Electricity used to cook              N
# 175                         Electricity used for other              N
# 176                          Natural gas used for heat              N
# 177                           Natural gas used for H2O              N
# 178                           Natural gas used to cook              N
# 179                         Natural gas used for other              N
# 180                                        HH uses LPG              N
# 181                          Bottled gas used for heat              N
# 182                           Bottled gas used for H2O              Y
# 183                           Bottled gas used to cook              N
# 184                                   HH uses Fuel oil              N
# 185                             Fuel oil used for heat              N
# 186                              Fuel oil used for H2O              N
# 187                                       HH uses Wood              N
# 188     Use Wood logs or split wood as a fuel in house              N
# 189                Use Wood pellets as a fuel in house              N
# 190                                Wood used for other              N
# 191                                 Wood used for heat              N
# 192                                  Wood used for H2O              N
# 193                                      HH uses solar              N
# 194                                 Solar used for H2O              N
# 195                               Solar used for other              N
# 196     Total of All TV, Audio, Stereo, VCR, DVD etc.,              Y
# 197  Total of Desktop, laptop, printer, fax, copier...              Y
# 198  Total of all phones including smartphone and r...              Y
#
#      COLUMN_TYPE  REQ_ONEHOTENC
# 0      Numerical          False
# 1      Numerical          False
# 2    Categorical           True
# 3    Categorical           True
# 4    Categorical           True
# 5    Categorical           True
# 6      Numerical          False
# 7    Categorical           True
# 8    Categorical           True
# 9    Categorical           True
# 10     Numerical          False
# 11     Numerical          False
# 12     Numerical          False
# 13     Numerical          False
# 14     Numerical          False
# 15     Numerical          False
# 16   Categorical           True
# 17   Categorical           True
# 18   Categorical           True
# 19   Categorical           True
# 20   Categorical           True
# 21   Categorical           True
# 22   Categorical           True
# 23   Categorical           True
# 24   Categorical           True
# 25   Categorical           True
# 26   Categorical           True
# 27   Categorical           True
# 28     Numerical          False
# 29   Categorical           True
# ..           ...            ...
# 169  Categorical           True
# 170  Categorical           True
# 171  Categorical           True
# 172  Categorical           True
# 173  Categorical           True
# 174  Categorical           True
# 175  Categorical           True
# 176  Categorical           True
# 177  Categorical           True
# 178  Categorical           True
# 179  Categorical           True
# 180  Categorical           True
# 181  Categorical           True
# 182  Categorical           True
# 183  Categorical           True
# 184  Categorical           True
# 185  Categorical           True
# 186  Categorical           True
# 187  Categorical           True
# 188  Categorical           True
# 189  Categorical           True
# 190  Categorical           True
# 191  Categorical           True
# 192  Categorical           True
# 193  Categorical           True
# 194  Categorical           True
# 195  Categorical           True
# 196    Numerical          False
# 197    Numerical          False
# 198    Numerical          False
#
# [199 rows x 7 columns]

# %%
raw_df.describe()
# Out:
#            RECSYEAR         DOEID       REGIONC      DIVISION       TYPEHUQ  \
# count  22591.000000  22591.000000  22591.000000  22591.000000  22591.000000
# mean    2008.802576   7195.131247      2.651498      5.382453      2.638484
# std        4.762735   4402.416131      1.045644      2.821670      1.184945
# min     2001.000000      1.000000      1.000000      1.000000      1.000000
# 25%     2009.000000   3330.000000      2.000000      3.000000      2.000000
# 50%     2009.000000   6474.000000      3.000000      5.000000      2.000000
# 75%     2015.000000  11061.000000      3.000000      7.000000      3.000000
# max     2015.000000  15686.000000      4.000000     10.000000      5.000000
#
#              CELLAR       STORIES      PRKGPLC1      YEARMADE       OCCUPYY  \
# count  22591.000000  22591.000000  22591.000000  22591.000000  22591.000000
# mean       0.143199     15.248373      0.475897      4.050640      6.796069
# std        2.250864     20.100299      2.239042      2.246379      1.992055
# min       -2.000000     -2.000000     -2.000000      1.000000      1.000000
# 25%       -2.000000     10.000000      0.000000      2.000000      6.000000
# 50%        0.000000     10.000000      0.000000      4.000000      7.000000
# 75%        1.000000     20.000000      1.000000      6.000000      8.000000
# max        9.000000     99.000000      9.000000     13.000000      9.000000
#
#            ...           WDPELLET       WDOTHER        WDWARM       WDWATER  \
# count      ...       22591.000000  22591.000000  22591.000000  22591.000000
# mean       ...           0.255544     -1.387411      0.114824      0.001284
# std        ...           4.179991      0.927600      0.318817      0.035807
# min        ...          -2.000000     -2.000000      0.000000      0.000000
# 25%        ...          -2.000000     -2.000000      0.000000      0.000000
# 50%        ...          -2.000000     -2.000000      0.000000      0.000000
# 75%        ...           0.000000      0.000000      0.000000      0.000000
# max        ...           9.000000      1.000000      1.000000      1.000000
#
#            USESOLAR      SOLWATER      SOLOTHER  TVAUDIOEQUIP    PCOFFEQUIP  \
# count  22591.000000  22591.000000  22591.000000  22591.000000  22591.000000
# mean       0.010579      0.002523      0.006994      6.695720      2.764110
# std        0.102313      0.050168      0.083339      3.735064      2.343253
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      4.000000      1.000000
# 50%        0.000000      0.000000      0.000000      6.000000      3.000000
# 75%        0.000000      0.000000      0.000000      9.000000      4.000000
# max        1.000000      1.000000      1.000000     43.000000     23.000000
#
#               PHONE
# count  22591.000000
# mean       1.534107
# std        1.120486
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max       10.000000
#
# [8 rows x 189 columns]

# %%
#from sklearn.preprocessing import StandardScaler
#features =raw_df[[']]

# %% [markdown]
# # Data Preparation

# %%
# Extract features and labels
labels = raw_df['TOTALBTU']
#labels = raw_df['TOTALDOLLAR']
#raw_df = features.drop('TYPEHUQ', axis = 1)

# %%
# List of features for later use

#model = df_cols[df_cols.FEATURES_MODEL == "Y"].COLUMN_NAME
#modelDF=model.drop(columns=['TOTALBTU'])

#feature=modelDF
#print(modelDF)
#features = list(features.columns)

# %%
# Convert to numpy array
features_X,columns_names = generateX()
# Out:
#  X Features shape : (22591, 87)
# cols with values as 99 and -2: ['CELLAR', 'STORIES', 'PRKGPLC1', 'BEDROOMS', 'FUELPOOL', 'SIZRFRI1', 'TYPERFR1', 'AGERFRI1', 'SIZRFRI2', 'TYPERFR2', 'AGERFRI2', 'NUMFREEZ', 'SIZFREEZ', 'AGEFRZR', 'STOVENFUEL', 'OVENUSE', 'AMTMICRO', 'DWASHUSE', 'WASHLOAD', 'WASHTEMP', 'EQUIPM', 'FUELHEAT', 'EQUIPAGE', 'PROTHERM', 'TEMPHOME', 'TEMPGONE', 'TEMPNITE', 'AGECENAC', 'USECENAC', 'NUMBERAC', 'WWACAGE', 'USEWWAC', 'FUELH2O', 'WHEATAGE', 'WHEATSIZ', 'LGTOUTNUM', 'ESDISHW', 'PGASHEAT', 'WOODAMT']
#
# Duplicate Count : 0
# shape of X is (22591, 79)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features_X, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (16943, 79)
# Training Labels Shape: (16943,)
# Testing Features Shape: (5648, 79)
# Testing Labels Shape: (5648,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 10 decision trees

rf = RandomForestRegressor(n_estimators = 50, random_state = 42, max_depth = 11)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Import the model we are using (modifying model to fit)
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 10 decision trees

rf = RandomForestRegressor(n_estimators = 50, random_state = 42, max_depth = 10)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
from sklearn.metrics import mean_squared_error
predictions = rf.predict(test_features)
MSE = mean_squared_error(test_labels, predictions)

r2 = rf.score(test_features, test_labels)
print(MSE)
print(r2)
# Out:
# 189872201.296754
# 0.9373234435085818

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf.feature_importances_
importances

# %%
# We can sort the features by their importance
df=pd.DataFrame(sorted(zip(rf.feature_importances_,columns_names), reverse=True))

# %%
g = sns.pairplot(raw_df,
x_vars=["TOTALBTU"],
y_vars=['CUFEETNG','BTUELOTH', 'BTUFO','BTUEL','GALLONLP','FUELHEAT','TOTHSQFT','HDD65','BTUELCOL','BTUELRFG'])

# %%
g = sns.pairplot(raw_df,
x_vars=["TOTALDOLLAR"],
y_vars=['CUFEETNG','BTUELOTH', 'BTUFO','BTUEL','GALLONLP','FUELHEAT','TOTHSQFT','HDD65','BTUELCOL','BTUELRFG'])
