# %%
import pandas as pd
import pylab as pl
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_variables = pd.read_csv("../Project3/final_feature_selection_btu.csv")
raw_variables.loc[~(raw_variables==0).all(axis=1)]
y = raw_variables[['TOTALBTU']].values
x = raw_variables[['TOTHSQFT']].values

raw_variables[['TOTALBTU', 'TOTHSQFT']]
# Out:
#          TOTALBTU  TOTHSQFT
# 0      156762.000      2395
# 1      123042.000      2437
# 2       19192.000         0
# 3      922899.000      5685
# 4       31187.000         0
# 5       14849.000         0
# 6       20380.000         0
# 7       27504.000         0
# 8      169160.000      1041
# 9       35603.000      1022
# 10      50453.000         0
# 11     124268.000       873
# 12      96965.000      1158
# 13      18230.000       491
# 14     102358.000      1560
# 15      72372.000      1410
# 16      35539.000      1225
# 17      91855.000      4309
# 18     112576.000      2280
# 19      14038.000      1240
# 20       9588.000       936
# 21       8411.000       780
# 22      23792.000      1878
# 23     137630.000       891
# 24      33996.000       857
# 25      46741.000      1409
# 26      48412.000      1234
# 27     142116.000      2008
# 28     167902.000      3544
# 29     118509.000      2006
# ...           ...       ...
# 26943   80643.555      1148
# 26944   26704.722      1351
# 26945   81174.637       842
# 26946   30158.174      1039
# 26947  131652.245      2400
# 26948  233260.128      4338
# 26949   20123.695       631
# 26950  191860.101      3000
# 26951   42192.352      1448
# 26952  245184.925      4284
# 26953   97959.784      2355
# 26954  210121.409      2655
# 26955   72309.956      1438
# 26956   97400.851      5508
# 26957   73030.395      2870
# 26958  154130.242      1679
# 26959   43488.742      1307
# 26960  285353.626      5910
# 26961   82286.478      1344
# 26962   78383.841      1911
# 26963   88265.042      2194
# 26964  107062.381       912
# 26965   91567.239      2362
# 26966   71584.398      1073
# 26967   86552.105      1848
# 26968   31029.024       456
# 26969   24254.443       980
# 26970   16298.935       893
# 26971   54181.680      2014
# 26972   39343.813      1232
#
# [26973 rows x 2 columns]

# %%
Nc = range(1, 20)

kmeans = [KMeans(n_clusters=i) for i in Nc]

kmeans
# Out:
# [KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=1, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=9, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=11, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=12, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=13, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=14, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=15, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=16, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=17, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=18, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#      n_clusters=19, n_init=10, n_jobs=1, precompute_distances='auto',
#      random_state=None, tol=0.0001, verbose=0)]

# %%
score = [kmeans[i].fit(y).score(y) for i in range(len(kmeans))]

score
# Out:
# [-1.6577401163994673e+19,
#  -9.053862131169609e+17,
#  -2.0925033578586822e+17,
#  -77741502864605.28,
#  -38017388289071.92,
#  -26958711838851.4,
#  -21690118082202.656,
#  -16076712421904.305,
#  -13332332573447.807,
#  -11434346674387.637,
#  -9917701547068.95,
#  -8857216219558.812,
#  -7607270481789.863,
#  -7280366162621.982,
#  -6330152870675.055,
#  -5575163718054.221,
#  -5025594351906.415,
#  -4477712620248.538,
#  -4080191283019.28]

# %%
pl.plot(Nc,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.grid()
pl.show()

# %%
pca = PCA(n_components=1).fit(y)

pca_d = pca.transform(y)

pca_c = pca.transform(x)

# %%
kmeans=KMeans(n_clusters=2)

kmeansoutput=kmeans.fit(y)

kmeansoutput
labels = kmeansoutput.labels_
pl.figure('Cluster Output K-Means')

pl.scatter(pca_c[:, 0], pca_d[:, 0], c=kmeansoutput.labels_)

pl.xlabel('XLabel')

pl.ylabel('YLabel')

pl.title('3 Cluster K-Means')

pl.show()

# %%
kmeans=KMeans(n_clusters=8)

kmeansoutput=kmeans.fit(y)

kmeansoutput
labels = kmeansoutput.labels_
pl.figure('Cluster Output K-Means')

pl.scatter(pca_c[:, 0], pca_d[:, 0], c=kmeansoutput.labels_)

pl.xlabel('XLabel')

pl.ylabel('YLabel')

pl.title('3 Cluster K-Means')

pl.show()
