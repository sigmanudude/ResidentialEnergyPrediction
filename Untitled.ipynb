# %%
import pandas as pd
import pylab as pl
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_variables = pd.read_csv("../Project3/dataforfinalproject/PCAcomponentoutput.csv")

y = raw_variables[['REGIONC']]
x = raw_variables[['TOTALBTU']]

# %%
cluster = KMeans(n_clusters =5)

# %%
raw_variables["cluster"] = cluster.fit_predict(x,y)

# %%
raw_variables.tail()
# Out:
#        Unnamed: 0   REGIONC  DIVISION   TYPEHUQ    CELLAR   STORIES  PRKGPLC1  \
# 21425       21425 -3.150852 -1.170942 -5.577158  4.774045  0.312117  1.085661
# 21426       21426 -2.134114 -0.221514 -3.415102  0.874471 -1.134773 -0.338256
# 21427       21427 -2.859519 -0.022473 -7.214093  1.561766 -0.673730  0.007212
# 21428       21428 -1.902644  1.269169 -0.171706 -4.030097 -2.532657 -2.303134
# 21429       21429 -3.446697  0.585147 -6.098177 -0.130641 -1.663072 -1.066466
#
#        YEARMADE   OCCUPYY  BEDROOMS   ...         POOL   RECBATH   FUELTUB  \
# 21425 -0.393105 -2.417505 -2.079718   ...     0.017658 -0.023347  0.075124
# 21426 -0.757826  0.143342 -1.829825   ...    -0.253549  0.025525 -0.007197
# 21427 -0.733484 -2.702599 -2.361546   ...    -0.054878  0.011773  0.039056
# 21428 -0.698699  1.998723 -1.922047   ...     0.071006  0.020359  0.010680
# 21429 -1.346759 -3.425856 -1.583308   ...    -0.094136  0.006420  0.019771
#
#         NUMFRIG  UPRTFRZR    STOVEN     STOVE      OVEN     MICRO  cluster
# 21425  0.222985  0.121607 -0.156138 -0.055323  0.088206 -0.105921        4
# 21426  0.080144  0.166785 -0.093242  0.020744  0.037065  0.064168        3
# 21427  0.012381  0.053948 -0.072349  0.035613  0.004229  0.041644        4
# 21428  0.051080 -0.031001  0.291307 -0.001383 -0.051421  0.008719        0
# 21429  0.055235  0.012301 -0.127969  0.064297 -0.023154  0.092140        3
#
# [5 rows x 152 columns]

# %%
pca = PCA(n_components = 1).fit(y,x)
pca_d = pca.transform(y)

pca_c = pca.transform(x)

# %%
kmeansoutput=cluster.fit(y)

kmeansoutput


pl.figure('KMeans Cluster of Regions with TOTALBTU')

pl.scatter(pca_c[:, 0], pca_d[:, 0])

pl.xlabel('Data Correlation')
pl.grid()
pl.ylabel('Accuracy')
pl.title('KMeans Cluster of Regions with TOTALBTU')
#plt.savefig('C:/Users/justi/Desktop/homework/Project3/dataforfinalproject/Pictures/KMEANSCluser.png')
pl.show()

# %%
loading_scores = pd.Series(pca.components_[0])
sorted_loading_scores = loading_scores.abs().sort_values(ascending=False)
top_10_features = sorted_loading_scores[0:20].index.values
print(loading_scores[top_10_features])
